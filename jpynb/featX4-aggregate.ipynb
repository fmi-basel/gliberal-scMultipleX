# %%
from faim_hcs.hcs.Experiment import Experiment
from faim_hcs.records.PlateRecord import PlateRecord
from faim_hcs.records.WellRecord import WellRecord
from faim_hcs.records.OrganoidRecord import OrganoidRecord

from glob import glob

import os
from os.path import join

from os.path import isdir, dirname, split, basename, splitext, exists
from tqdm.notebook import tqdm

import re

import pandas as pd

from skimage.measure import regionprops, label
from skimage.morphology import binary_erosion
import numpy as np
import math 
import copy

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## User input

# %%
# Load an existing faim-hcs Experiment from disk. 
exp = Experiment()
exp.load('/tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220528_GCPLEX_redo/20220507GCPLEX_R0/summary.csv')

# %% [markdown]
# ## Merge organoid features into single df

# %%
#pool together regionprops_org files
exp.only_iterate_over_wells(False)
exp.reset_iterator()

#create list of dataframes from all well and organoids
org_feat_df_list =[] #length of list is #plates * # wells * #channels * # organoids/well

#add nuclear counts as well, if there is a nuc seg. this is only raw counts, before filtering or nuc/mem linking!
for organoid in exp:
    nuc_count = 0 #default is 0
    try:
        n = organoid.get_measurement('regionprops_nuc_C01')
    except Exception as e:
        print(organoid.organoid_id, organoid.well.well_id, organoid.well.plate.plate_id, 
              "missing nuc seg", e) #usually exception is that no nuc were detected so csv is empty
    else: #if there is no error, count number of nuclei in organoid
        if n is not None:
            nuc_count = n.shape[0]
        
    for meas_name in [k for k,v in organoid.measurements.items() if k.startswith('regionprops_org')]:
        m = organoid.get_measurement(meas_name)
        m["nuc_count"] = nuc_count #add nuc count to measurement
        org_feat_df_list.append(m)

org_feat_df = pd.concat(org_feat_df_list, ignore_index=True, sort=False)
# Out:
# object_58 B03 day2p5 missing nuc seg No columns to parse from file
# object_86 B03 day2p5 missing nuc seg No columns to parse from file
# object_43 B03 day2p5 missing nuc seg No columns to parse from file
# object_75 B03 day2p5 missing nuc seg No columns to parse from file
# object_33 B03 day2p5 missing nuc seg No columns to parse from file
# object_39 B03 day2p5 missing nuc seg No columns to parse from file
# object_23 B03 day2p5 missing nuc seg No columns to parse from file
# object_70 B03 day2p5 missing nuc seg No columns to parse from file
# object_76 B03 day2p5 missing nuc seg No columns to parse from file
# object_83 B03 day2p5 missing nuc seg No columns to parse from file
# object_53 B03 day2p5 missing nuc seg No columns to parse from file
# object_26 B03 day2p5 missing nuc seg No columns to parse from file
# object_13 B05 day2p5 missing nuc seg No columns to parse from file
# object_65 B05 day2p5 missing nuc seg No columns to parse from file
# object_75 B05 day2p5 missing nuc seg No columns to parse from file
# object_33 B05 day2p5 missing nuc seg No columns to parse from file
# object_84 B05 day2p5 missing nuc seg No columns to parse from file
# object_15 B05 day2p5 missing nuc seg No columns to parse from file
# object_129 B05 day2p5 missing nuc seg No columns to parse from file
# object_99 B05 day2p5 missing nuc seg No columns to parse from file
# object_63 B05 day2p5 missing nuc seg No columns to parse from file
# object_118 B05 day2p5 missing nuc seg No columns to parse from file
# object_50 B05 day2p5 missing nuc seg No columns to parse from file
# object_38 B05 day2p5 missing nuc seg No columns to parse from file
# object_122 B05 day2p5 missing nuc seg No columns to parse from file
# object_31 B05 day2p5 missing nuc seg No columns to parse from file
# object_77 B05 day2p5 missing nuc seg No columns to parse from file
# object_71 B05 day2p5 missing nuc seg No columns to parse from file
# object_10 B05 day2p5 missing nuc seg No columns to parse from file
# object_14 B05 day2p5 missing nuc seg No columns to parse from file
# object_42 B05 day2p5 missing nuc seg No columns to parse from file
# object_83 B05 day2p5 missing nuc seg No columns to parse from file
# object_6 B05 day2p5 missing nuc seg No columns to parse from file
# object_97 B05 day2p5 missing nuc seg No columns to parse from file
# object_26 B05 day2p5 missing nuc seg No columns to parse from file
# object_17 B04 day2p5 missing nuc seg No columns to parse from file
# object_23 B04 day2p5 missing nuc seg No columns to parse from file
# object_21 B04 day2p5 missing nuc seg No columns to parse from file
# object_27 B04 day2p5 missing nuc seg No columns to parse from file
# object_70 B04 day2p5 missing nuc seg No columns to parse from file
# object_102 B04 day2p5 missing nuc seg No columns to parse from file
# object_106 B04 day2p5 missing nuc seg No columns to parse from file
# object_63 B04 day2p5 missing nuc seg No columns to parse from file
# object_48 B04 day2p5 missing nuc seg No columns to parse from file
# object_94 B04 day2p5 missing nuc seg No columns to parse from file
# object_104 B04 day2p5 missing nuc seg No columns to parse from file
# object_73 B04 day2p5 missing nuc seg No columns to parse from file
# object_4 B04 day2p5 missing nuc seg No columns to parse from file
# object_49 B06 day2p5 missing nuc seg No columns to parse from file
# object_95 B06 day2p5 missing nuc seg No columns to parse from file
# object_35 B06 day2p5 missing nuc seg No columns to parse from file
# object_111 B06 day2p5 missing nuc seg No columns to parse from file
# object_65 B06 day2p5 missing nuc seg No columns to parse from file
# object_70 B06 day2p5 missing nuc seg No columns to parse from file
# object_102 B06 day2p5 missing nuc seg No columns to parse from file
# object_105 B06 day2p5 missing nuc seg No columns to parse from file
# object_110 B06 day2p5 missing nuc seg No columns to parse from file
# object_40 B06 day2p5 missing nuc seg No columns to parse from file
# object_19 B06 day2p5 missing nuc seg No columns to parse from file
# object_125 B06 day2p5 missing nuc seg No columns to parse from file
# object_92 B06 day2p5 missing nuc seg No columns to parse from file
# object_31 B06 day2p5 missing nuc seg No columns to parse from file
# object_71 B06 day2p5 missing nuc seg No columns to parse from file
# object_42 B06 day2p5 missing nuc seg No columns to parse from file
# object_81 B06 day2p5 missing nuc seg No columns to parse from file
# object_74 B03 day1p5 missing nuc seg No columns to parse from file
# object_35 B03 day1p5 missing nuc seg No columns to parse from file
# object_47 B03 day1p5 missing nuc seg No columns to parse from file
# object_75 B03 day1p5 missing nuc seg No columns to parse from file
# object_27 B03 day1p5 missing nuc seg No columns to parse from file
# object_72 B03 day1p5 missing nuc seg No columns to parse from file
# object_19 B03 day1p5 missing nuc seg No columns to parse from file
# object_62 B03 day1p5 missing nuc seg No columns to parse from file
# object_77 B03 day1p5 missing nuc seg No columns to parse from file
# object_14 B03 day1p5 missing nuc seg No columns to parse from file
# object_74 B05 day1p5 missing nuc seg No columns to parse from file
# object_39 B05 day1p5 missing nuc seg No columns to parse from file
# object_29 B05 day1p5 missing nuc seg No columns to parse from file
# object_85 B05 day1p5 missing nuc seg No columns to parse from file
# object_53 B05 day1p5 missing nuc seg No columns to parse from file
# object_64 B05 day1p5 missing nuc seg No columns to parse from file
# object_12 B04 day1p5 missing nuc seg No columns to parse from file
# object_57 B04 day1p5 missing nuc seg No columns to parse from file
# object_82 B04 day1p5 missing nuc seg No columns to parse from file
# object_33 B04 day1p5 missing nuc seg No columns to parse from file
# object_16 B04 day1p5 missing nuc seg No columns to parse from file
# object_88 B04 day1p5 missing nuc seg No columns to parse from file
# object_79 B06 day1p5 missing nuc seg No columns to parse from file
# object_32 B06 day1p5 missing nuc seg No columns to parse from file
# object_62 B06 day1p5 missing nuc seg No columns to parse from file
# object_88 B06 day1p5 missing nuc seg No columns to parse from file
# Measurment regionprops_nuc_C01 does not exist in object_13:[].
# Measurment regionprops_nuc_C01 does not exist in object_12:[].
# Measurment regionprops_nuc_C01 does not exist in object_57:[].
# Measurment regionprops_nuc_C01 does not exist in object_49:[].
# Measurment regionprops_nuc_C01 does not exist in object_60:[].
# Measurment regionprops_nuc_C01 does not exist in object_35:[].
# Measurment regionprops_nuc_C01 does not exist in object_54:[].
# Measurment regionprops_nuc_C01 does not exist in object_46:[].
# Measurment regionprops_nuc_C01 does not exist in object_58:[].
# Measurment regionprops_nuc_C01 does not exist in object_17:[].
# Measurment regionprops_nuc_C01 does not exist in object_43:[].
# Measurment regionprops_nuc_C01 does not exist in object_32:[].
# Measurment regionprops_nuc_C01 does not exist in object_11:[].
# Measurment regionprops_nuc_C01 does not exist in object_47:[].
# Measurment regionprops_nuc_C01 does not exist in object_55:[].
# Measurment regionprops_nuc_C01 does not exist in object_41:[].
# Measurment regionprops_nuc_C01 does not exist in object_51:[].
# Measurment regionprops_nuc_C01 does not exist in object_61:[].
# Measurment regionprops_nuc_C01 does not exist in object_39:[].
# Measurment regionprops_nuc_C01 does not exist in object_15:[].
# Measurment regionprops_nuc_C01 does not exist in object_23:[].
# Measurment regionprops_nuc_C01 does not exist in object_21:[].
# Measurment regionprops_nuc_C01 does not exist in object_27:[].
# Measurment regionprops_nuc_C01 does not exist in object_29:[].
# Measurment regionprops_nuc_C01 does not exist in object_25:[].
# Measurment regionprops_nuc_C01 does not exist in object_36:[].
# Measurment regionprops_nuc_C01 does not exist in object_20:[].
# Measurment regionprops_nuc_C01 does not exist in object_40:[].
# Measurment regionprops_nuc_C01 does not exist in object_45:[].
# Measurment regionprops_nuc_C01 does not exist in object_19:[].
# Measurment regionprops_nuc_C01 does not exist in object_48:[].
# Measurment regionprops_nuc_C01 does not exist in object_34:[].
# Measurment regionprops_nuc_C01 does not exist in object_52:[].
# Measurment regionprops_nuc_C01 does not exist in object_18:[].
# Measurment regionprops_nuc_C01 does not exist in object_3:[].
# Measurment regionprops_nuc_C01 does not exist in object_2:[].
# Measurment regionprops_nuc_C01 does not exist in object_50:[].
# Measurment regionprops_nuc_C01 does not exist in object_30:[].
# Measurment regionprops_nuc_C01 does not exist in object_1:[].
# Measurment regionprops_nuc_C01 does not exist in object_38:[].
# Measurment regionprops_nuc_C01 does not exist in object_16:[].
# Measurment regionprops_nuc_C01 does not exist in object_56:[].
# Measurment regionprops_nuc_C01 does not exist in object_31:[].
# Measurment regionprops_nuc_C01 does not exist in object_10:[].
# Measurment regionprops_nuc_C01 does not exist in object_28:[].
# Measurment regionprops_nuc_C01 does not exist in object_22:[].
# Measurment regionprops_nuc_C01 does not exist in object_59:[].
# Measurment regionprops_nuc_C01 does not exist in object_14:[].
# Measurment regionprops_nuc_C01 does not exist in object_24:[].
# Measurment regionprops_nuc_C01 does not exist in object_42:[].
# Measurment regionprops_nuc_C01 does not exist in object_9:[].
# Measurment regionprops_nuc_C01 does not exist in object_8:[].
# Measurment regionprops_nuc_C01 does not exist in object_44:[].
# Measurment regionprops_nuc_C01 does not exist in object_7:[].
# Measurment regionprops_nuc_C01 does not exist in object_53:[].
# Measurment regionprops_nuc_C01 does not exist in object_6:[].
# Measurment regionprops_nuc_C01 does not exist in object_5:[].
# Measurment regionprops_nuc_C01 does not exist in object_37:[].
# Measurment regionprops_nuc_C01 does not exist in object_4:[].
# Measurment regionprops_nuc_C01 does not exist in object_13:[].
# Measurment regionprops_nuc_C01 does not exist in object_12:[].
# Measurment regionprops_nuc_C01 does not exist in object_57:[].
# Measurment regionprops_nuc_C01 does not exist in object_49:[].
# Measurment regionprops_nuc_C01 does not exist in object_60:[].
# Measurment regionprops_nuc_C01 does not exist in object_74:[].
# Measurment regionprops_nuc_C01 does not exist in object_35:[].
# Measurment regionprops_nuc_C01 does not exist in object_54:[].
# Measurment regionprops_nuc_C01 does not exist in object_46:[].
# Measurment regionprops_nuc_C01 does not exist in object_65:[].
# Measurment regionprops_nuc_C01 does not exist in object_17:[].
# Measurment regionprops_nuc_C01 does not exist in object_43:[].
# Measurment regionprops_nuc_C01 does not exist in object_32:[].
# Measurment regionprops_nuc_C01 does not exist in object_11:[].
# Measurment regionprops_nuc_C01 does not exist in object_47:[].
# Measurment regionprops_nuc_C01 does not exist in object_55:[].
# Measurment regionprops_nuc_C01 does not exist in object_75:[].
# Measurment regionprops_nuc_C01 does not exist in object_41:[].
# Measurment regionprops_nuc_C01 does not exist in object_33:[].
# Measurment regionprops_nuc_C01 does not exist in object_51:[].
# Measurment regionprops_nuc_C01 does not exist in object_61:[].
# Measurment regionprops_nuc_C01 does not exist in object_15:[].
# Measurment regionprops_nuc_C01 does not exist in object_23:[].
# Measurment regionprops_nuc_C01 does not exist in object_21:[].
# Measurment regionprops_nuc_C01 does not exist in object_27:[].
# Measurment regionprops_nuc_C01 does not exist in object_29:[].
# Measurment regionprops_nuc_C01 does not exist in object_70:[].
# Measurment regionprops_nuc_C01 does not exist in object_25:[].
# Measurment regionprops_nuc_C01 does not exist in object_36:[].
# Measurment regionprops_nuc_C01 does not exist in object_66:[].
# Measurment regionprops_nuc_C01 does not exist in object_20:[].
# Measurment regionprops_nuc_C01 does not exist in object_40:[].
# Measurment regionprops_nuc_C01 does not exist in object_45:[].
# Measurment regionprops_nuc_C01 does not exist in object_72:[].
# Measurment regionprops_nuc_C01 does not exist in object_69:[].
# Measurment regionprops_nuc_C01 does not exist in object_19:[].
# Measurment regionprops_nuc_C01 does not exist in object_63:[].
# Measurment regionprops_nuc_C01 does not exist in object_48:[].
# Measurment regionprops_nuc_C01 does not exist in object_34:[].
# Measurment regionprops_nuc_C01 does not exist in object_76:[].
# Measurment regionprops_nuc_C01 does not exist in object_62:[].
# Measurment regionprops_nuc_C01 does not exist in object_52:[].
# Measurment regionprops_nuc_C01 does not exist in object_18:[].
# Measurment regionprops_nuc_C01 does not exist in object_3:[].
# Measurment regionprops_nuc_C01 does not exist in object_2:[].
# Measurment regionprops_nuc_C01 does not exist in object_50:[].
# Measurment regionprops_nuc_C01 does not exist in object_30:[].
# Measurment regionprops_nuc_C01 does not exist in object_1:[].
# Measurment regionprops_nuc_C01 does not exist in object_38:[].
# Measurment regionprops_nuc_C01 does not exist in object_16:[].
# Measurment regionprops_nuc_C01 does not exist in object_56:[].
# Measurment regionprops_nuc_C01 does not exist in object_31:[].
# Measurment regionprops_nuc_C01 does not exist in object_71:[].
# Measurment regionprops_nuc_C01 does not exist in object_10:[].
# Measurment regionprops_nuc_C01 does not exist in object_28:[].
# Measurment regionprops_nuc_C01 does not exist in object_59:[].
# Measurment regionprops_nuc_C01 does not exist in object_14:[].
# Measurment regionprops_nuc_C01 does not exist in object_24:[].
# Measurment regionprops_nuc_C01 does not exist in object_42:[].
# Measurment regionprops_nuc_C01 does not exist in object_73:[].
# Measurment regionprops_nuc_C01 does not exist in object_67:[].
# Measurment regionprops_nuc_C01 does not exist in object_9:[].
# Measurment regionprops_nuc_C01 does not exist in object_8:[].
# Measurment regionprops_nuc_C01 does not exist in object_44:[].
# Measurment regionprops_nuc_C01 does not exist in object_53:[].
# Measurment regionprops_nuc_C01 does not exist in object_64:[].
# Measurment regionprops_nuc_C01 does not exist in object_68:[].
# Measurment regionprops_nuc_C01 does not exist in object_5:[].
# Measurment regionprops_nuc_C01 does not exist in object_37:[].
# Measurment regionprops_nuc_C01 does not exist in object_4:[].
# Measurment regionprops_nuc_C01 does not exist in object_26:[].
# Measurment regionprops_nuc_C01 does not exist in object_13:[].
# Measurment regionprops_nuc_C01 does not exist in object_12:[].
# Measurment regionprops_nuc_C01 does not exist in object_17:[].
# Measurment regionprops_nuc_C01 does not exist in object_32:[].
# Measurment regionprops_nuc_C01 does not exist in object_11:[].
# Measurment regionprops_nuc_C01 does not exist in object_41:[].
# Measurment regionprops_nuc_C01 does not exist in object_33:[].
# Measurment regionprops_nuc_C01 does not exist in object_39:[].
# Measurment regionprops_nuc_C01 does not exist in object_15:[].
# Measurment regionprops_nuc_C01 does not exist in object_23:[].
# Measurment regionprops_nuc_C01 does not exist in object_21:[].
# Measurment regionprops_nuc_C01 does not exist in object_29:[].
# Measurment regionprops_nuc_C01 does not exist in object_25:[].
# Measurment regionprops_nuc_C01 does not exist in object_36:[].
# Measurment regionprops_nuc_C01 does not exist in object_20:[].
# Measurment regionprops_nuc_C01 does not exist in object_40:[].
# Measurment regionprops_nuc_C01 does not exist in object_19:[].
# Measurment regionprops_nuc_C01 does not exist in object_34:[].
# Measurment regionprops_nuc_C01 does not exist in object_18:[].
# Measurment regionprops_nuc_C01 does not exist in object_3:[].
# Measurment regionprops_nuc_C01 does not exist in object_2:[].
# Measurment regionprops_nuc_C01 does not exist in object_30:[].
# Measurment regionprops_nuc_C01 does not exist in object_38:[].
# Measurment regionprops_nuc_C01 does not exist in object_16:[].
# Measurment regionprops_nuc_C01 does not exist in object_10:[].
# Measurment regionprops_nuc_C01 does not exist in object_28:[].
# Measurment regionprops_nuc_C01 does not exist in object_22:[].
# Measurment regionprops_nuc_C01 does not exist in object_14:[].
# Measurment regionprops_nuc_C01 does not exist in object_24:[].
# Measurment regionprops_nuc_C01 does not exist in object_42:[].
# Measurment regionprops_nuc_C01 does not exist in object_9:[].
# Measurment regionprops_nuc_C01 does not exist in object_8:[].
# Measurment regionprops_nuc_C01 does not exist in object_7:[].
# Measurment regionprops_nuc_C01 does not exist in object_6:[].
# Measurment regionprops_nuc_C01 does not exist in object_5:[].
# Measurment regionprops_nuc_C01 does not exist in object_37:[].
# Measurment regionprops_nuc_C01 does not exist in object_4:[].
# Measurment regionprops_nuc_C01 does not exist in object_26:[].
# Measurment regionprops_nuc_C01 does not exist in object_13:[].
# Measurment regionprops_nuc_C01 does not exist in object_12:[].
# Measurment regionprops_nuc_C01 does not exist in object_49:[].
# Measurment regionprops_nuc_C01 does not exist in object_35:[].
# Measurment regionprops_nuc_C01 does not exist in object_54:[].
# Measurment regionprops_nuc_C01 does not exist in object_46:[].
# Measurment regionprops_nuc_C01 does not exist in object_17:[].
# Measurment regionprops_nuc_C01 does not exist in object_43:[].
# Measurment regionprops_nuc_C01 does not exist in object_32:[].
# Measurment regionprops_nuc_C01 does not exist in object_11:[].
# Measurment regionprops_nuc_C01 does not exist in object_47:[].
# Measurment regionprops_nuc_C01 does not exist in object_55:[].
# Measurment regionprops_nuc_C01 does not exist in object_51:[].
# Measurment regionprops_nuc_C01 does not exist in object_39:[].
# Measurment regionprops_nuc_C01 does not exist in object_15:[].
# Measurment regionprops_nuc_C01 does not exist in object_23:[].
# Measurment regionprops_nuc_C01 does not exist in object_21:[].
# Measurment regionprops_nuc_C01 does not exist in object_27:[].
# Measurment regionprops_nuc_C01 does not exist in object_29:[].
# Measurment regionprops_nuc_C01 does not exist in object_25:[].
# Measurment regionprops_nuc_C01 does not exist in object_36:[].
# Measurment regionprops_nuc_C01 does not exist in object_20:[].
# Measurment regionprops_nuc_C01 does not exist in object_40:[].
# Measurment regionprops_nuc_C01 does not exist in object_45:[].
# Measurment regionprops_nuc_C01 does not exist in object_19:[].
# Measurment regionprops_nuc_C01 does not exist in object_48:[].
# Measurment regionprops_nuc_C01 does not exist in object_34:[].
# Measurment regionprops_nuc_C01 does not exist in object_52:[].
# Measurment regionprops_nuc_C01 does not exist in object_18:[].
# Measurment regionprops_nuc_C01 does not exist in object_3:[].
# Measurment regionprops_nuc_C01 does not exist in object_2:[].
# Measurment regionprops_nuc_C01 does not exist in object_50:[].
# Measurment regionprops_nuc_C01 does not exist in object_30:[].
# Measurment regionprops_nuc_C01 does not exist in object_1:[].
# Measurment regionprops_nuc_C01 does not exist in object_38:[].
# Measurment regionprops_nuc_C01 does not exist in object_16:[].
# Measurment regionprops_nuc_C01 does not exist in object_56:[].
# Measurment regionprops_nuc_C01 does not exist in object_31:[].
# Measurment regionprops_nuc_C01 does not exist in object_10:[].
# Measurment regionprops_nuc_C01 does not exist in object_28:[].
# Measurment regionprops_nuc_C01 does not exist in object_22:[].
# Measurment regionprops_nuc_C01 does not exist in object_14:[].
# Measurment regionprops_nuc_C01 does not exist in object_24:[].
# Measurment regionprops_nuc_C01 does not exist in object_42:[].
# Measurment regionprops_nuc_C01 does not exist in object_9:[].
# Measurment regionprops_nuc_C01 does not exist in object_8:[].
# Measurment regionprops_nuc_C01 does not exist in object_44:[].
# Measurment regionprops_nuc_C01 does not exist in object_7:[].
# Measurment regionprops_nuc_C01 does not exist in object_53:[].
# Measurment regionprops_nuc_C01 does not exist in object_6:[].
# Measurment regionprops_nuc_C01 does not exist in object_5:[].
# Measurment regionprops_nuc_C01 does not exist in object_37:[].
# Measurment regionprops_nuc_C01 does not exist in object_4:[].
# Measurment regionprops_nuc_C01 does not exist in object_26:[].
# object_7 B03 day3p5 missing nuc seg No columns to parse from file
# object_65 B05 day3p5 missing nuc seg No columns to parse from file
# object_30 B05 day3p5 missing nuc seg No columns to parse from file
# object_80 B04 day3p5 missing nuc seg No columns to parse from file
# object_33 B04 day3p5 missing nuc seg No columns to parse from file
# object_31 B04 day3p5 missing nuc seg No columns to parse from file
# object_71 B04 day3p5 missing nuc seg No columns to parse from file
# object_15 B06 day3p5 missing nuc seg No columns to parse from file
# object_13 B03 day2 missing nuc seg No columns to parse from file
# object_12 B03 day2 missing nuc seg No columns to parse from file
# object_27 B03 day2 missing nuc seg No columns to parse from file
# object_69 B03 day2 missing nuc seg No columns to parse from file
# object_99 B03 day2 missing nuc seg No columns to parse from file
# object_48 B03 day2 missing nuc seg No columns to parse from file
# object_37 B03 day2 missing nuc seg No columns to parse from file
# object_55 B05 day2 missing nuc seg No columns to parse from file
# object_70 B05 day2 missing nuc seg No columns to parse from file
# object_40 B05 day2 missing nuc seg No columns to parse from file
# object_9 B05 day2 missing nuc seg No columns to parse from file
# object_47 B04 day2 missing nuc seg No columns to parse from file
# object_39 B04 day2 missing nuc seg No columns to parse from file
# object_25 B04 day2 missing nuc seg No columns to parse from file
# object_3 B04 day2 missing nuc seg No columns to parse from file
# object_38 B04 day2 missing nuc seg No columns to parse from file
# object_85 B04 day2 missing nuc seg No columns to parse from file
# object_6 B04 day2 missing nuc seg No columns to parse from file
# object_5 B04 day2 missing nuc seg No columns to parse from file
# object_93 B06 day2 missing nuc seg No columns to parse from file
# object_47 B06 day2 missing nuc seg No columns to parse from file
# object_27 B06 day2 missing nuc seg No columns to parse from file
# object_19 B06 day2 missing nuc seg No columns to parse from file
# object_48 B06 day2 missing nuc seg No columns to parse from file
# object_94 B06 day2 missing nuc seg No columns to parse from file
# object_85 B06 day2 missing nuc seg No columns to parse from file
# object_8 B06 day2 missing nuc seg No columns to parse from file
# object_6 B06 day2 missing nuc seg No columns to parse from file
# object_97 B06 day2 missing nuc seg No columns to parse from file
# object_46 B03 day3 missing nuc seg No columns to parse from file
# object_62 B03 day3 missing nuc seg No columns to parse from file
# object_38 B03 day3 missing nuc seg No columns to parse from file
# object_64 B03 day3 missing nuc seg No columns to parse from file
# object_13 B05 day3 missing nuc seg No columns to parse from file
# object_12 B05 day3 missing nuc seg No columns to parse from file
# object_93 B05 day3 missing nuc seg No columns to parse from file
# object_65 B05 day3 missing nuc seg No columns to parse from file
# object_91 B05 day3 missing nuc seg No columns to parse from file
# object_33 B05 day3 missing nuc seg No columns to parse from file
# object_36 B05 day3 missing nuc seg No columns to parse from file
# object_40 B05 day3 missing nuc seg No columns to parse from file
# object_1 B05 day3 missing nuc seg No columns to parse from file
# object_10 B05 day3 missing nuc seg No columns to parse from file
# object_87 B05 day3 missing nuc seg No columns to parse from file
# object_13 B04 day3 missing nuc seg No columns to parse from file
# object_74 B04 day3 missing nuc seg No columns to parse from file
# object_65 B04 day3 missing nuc seg No columns to parse from file
# object_82 B04 day3 missing nuc seg No columns to parse from file
# object_17 B04 day3 missing nuc seg No columns to parse from file
# object_33 B04 day3 missing nuc seg No columns to parse from file
# object_23 B04 day3 missing nuc seg No columns to parse from file
# object_70 B04 day3 missing nuc seg No columns to parse from file
# object_20 B04 day3 missing nuc seg No columns to parse from file
# object_63 B04 day3 missing nuc seg No columns to parse from file
# object_76 B04 day3 missing nuc seg No columns to parse from file
# object_59 B04 day3 missing nuc seg No columns to parse from file
# object_24 B04 day3 missing nuc seg No columns to parse from file
# object_73 B04 day3 missing nuc seg No columns to parse from file
# object_26 B04 day3 missing nuc seg No columns to parse from file
# object_13 B06 day3 missing nuc seg No columns to parse from file
# object_84 B06 day3 missing nuc seg No columns to parse from file
# object_27 B06 day3 missing nuc seg No columns to parse from file
# object_22 B06 day3 missing nuc seg No columns to parse from file
# object_8 B06 day3 missing nuc seg No columns to parse from file
# object_80 B03 day4 missing nuc seg No columns to parse from file
# object_46 B03 day4 missing nuc seg No columns to parse from file
# object_82 B03 day4 missing nuc seg No columns to parse from file
# object_11 B03 day4 missing nuc seg No columns to parse from file
# object_75 B03 day4 missing nuc seg No columns to parse from file
# object_70 B03 day4 missing nuc seg No columns to parse from file
# object_45 B03 day4 missing nuc seg No columns to parse from file
# object_63 B03 day4 missing nuc seg No columns to parse from file
# object_50 B03 day4 missing nuc seg No columns to parse from file
# object_1 B03 day4 missing nuc seg No columns to parse from file
# object_73 B03 day4 missing nuc seg No columns to parse from file
# object_67 B03 day4 missing nuc seg No columns to parse from file
# object_9 B03 day4 missing nuc seg No columns to parse from file
# object_6 B03 day4 missing nuc seg No columns to parse from file
# object_57 B05 day4 missing nuc seg No columns to parse from file
# object_79 B05 day4 missing nuc seg No columns to parse from file
# object_11 B05 day4 missing nuc seg No columns to parse from file
# object_84 B05 day4 missing nuc seg No columns to parse from file
# object_70 B05 day4 missing nuc seg No columns to parse from file
# object_36 B05 day4 missing nuc seg No columns to parse from file
# object_66 B05 day4 missing nuc seg No columns to parse from file
# object_20 B05 day4 missing nuc seg No columns to parse from file
# object_45 B05 day4 missing nuc seg No columns to parse from file
# object_77 B05 day4 missing nuc seg No columns to parse from file
# object_71 B05 day4 missing nuc seg No columns to parse from file
# object_9 B05 day4 missing nuc seg No columns to parse from file
# object_7 B05 day4 missing nuc seg No columns to parse from file
# object_53 B05 day4 missing nuc seg No columns to parse from file
# object_68 B05 day4 missing nuc seg No columns to parse from file
# object_37 B05 day4 missing nuc seg No columns to parse from file
# object_60 B04 day4 missing nuc seg No columns to parse from file
# object_41 B04 day4 missing nuc seg No columns to parse from file
# object_15 B04 day4 missing nuc seg No columns to parse from file
# object_2 B04 day4 missing nuc seg No columns to parse from file
# object_46 B06 day4 missing nuc seg No columns to parse from file
# object_61 B06 day4 missing nuc seg No columns to parse from file
# object_69 B06 day4 missing nuc seg No columns to parse from file
# object_10 B06 day4 missing nuc seg No columns to parse from file

# %%
#pool together regionprops_ovr files
exp.only_iterate_over_wells(True)
exp.reset_iterator()

#create list of ovr dataframes from all wells
org_ovr_df_list =[] #length of list is # plates * # wells

for well in exp:
    for meas_name in [k for k,v in well.measurements.items() if k.startswith('regionprops_ovr')]:
        m = well.get_measurement(meas_name)
        org_ovr_df_list.append(m)

org_ovr_df = pd.concat(org_ovr_df_list, ignore_index=True, sort=False)

# %%
# merge all org and ovr features into single df, includes all plates, wells, and organoids

org_df = pd.merge(org_feat_df, org_ovr_df, how="left", on=["hcs_experiment", "plate_id", "well_id", "organoid_id" ])
org_df = org_df.sort_values(by=["hcs_experiment", "root_dir", "plate_id", "well_id", "org_label", "channel_id"])

#add .fillna('NaN') at the end?

org_df.to_csv(join(exp.get_experiment_dir(),"org_df.csv"), index=False) #saves csv

# %% [markdown]
# ## Merge linking of organoids into single df - all rounds

# %%
# pool together organoid linking files
exp.only_iterate_over_wells(True)
exp.reset_iterator()

#create dictionary of lists containing linking files for each round
org_link_df_dict ={} #each key in dictionary is a round that was linked to R0

#initialize dictionary
for well in exp:
    linkMeasurements = [k for k,v in well.measurements.items() if k.startswith('linking_ovr')]
    
    # if no linking in folder, skip
    if not linkMeasurements:
        continue
    
    for meas_name in linkMeasurements:
        rnd = meas_name[-6:-4] # select the round name that was linked to R0
        org_link_df_dict[rnd] = [] #add to dictionary as empty list

#add linking files to dictionary
exp.only_iterate_over_wells(True)
exp.reset_iterator()
for well in exp:
    linkMeasurements = [k for k,v in well.measurements.items() if k.startswith('linking_ovr')]
    
    # if no linking in folder, skip
    if not linkMeasurements:
        continue
    
    for meas_name in linkMeasurements:
        m = well.get_measurement(meas_name)
        rnd = meas_name[-6:-4]
        org_link_df_dict[rnd].append(m)

# if there is organoid linking, concatenate and save csv
if not len(org_link_df_dict) == 0:
    for key in org_link_df_dict:
        link_df = pd.concat(org_link_df_dict[key], ignore_index=True, sort=False)
        link_df.to_csv(join(exp.get_experiment_dir(),("linking_org_" + key + "_df.csv")), index=False) #saves csv

# %% [markdown]
# ## PlatyMatch linking into single df

# %%
# pool together organoid linking files
exp.only_iterate_over_wells(False)
exp.reset_iterator()

#create dictionary of lists containing linking files for each round
nuc_link_df_dict ={} #each key in dictionary is a round that was linked to R0

#initialize dictionary, nested dictionary for each round
for organoid in exp:
    linkMeasurements = [k for k,v in organoid.measurements.items() if k.startswith('linking_nuc_ffd')]
    
    # if no linking in organoid, skip
    if not linkMeasurements:
        continue
    
    for meas_name in linkMeasurements:
        rnd = meas_name[-6:-4] # select the round name that was linked to R0
        nuc_link_df_dict[rnd] = [] #add to dictionary as empty list

#add linking files to dictionary
exp.only_iterate_over_wells(False)
exp.reset_iterator()
for organoid in exp:
    linkMeasurements = [k for k,v in organoid.measurements.items() if k.startswith('linking_nuc_ffd')]
    
    # if no linking in organoid, skip
    if not linkMeasurements:
        continue
    
    for meas_name in linkMeasurements:
        m = organoid.get_measurement(meas_name)
        rnd = meas_name[-6:-4]
        nuc_link_df_dict[rnd].append(m)

# if there is nuc linking, concatenate and save csv
if not len(nuc_link_df_dict) == 0:
    for key in nuc_link_df_dict:
        nuc_link_df = pd.concat(nuc_link_df_dict[key], ignore_index=True, sort=False)
        nuc_link_df.to_csv(join(exp.get_experiment_dir(),("linking_nuc_" + key + "_df.csv")), index=False) #saves csv

# %% [markdown]
# ## Merge nuclear features into single df

# %%
#pool together regionprops_nuc files
exp.only_iterate_over_wells(False)
exp.reset_iterator()

#create list of dataframes from all well and organoids
nuc_feat_df_list =[] #length of list is #plates * # wells * #channels * # organoids/well

for organoid in exp:
    nucMeasurements = [k for k,v in organoid.measurements.items() if k.startswith('regionprops_nuc')]
    
    # if no nuclear feature extraction in folder, skip
    if not nucMeasurements:
        continue
        
    for meas_name in nucMeasurements:
        try:
            m = organoid.get_measurement(meas_name)
        
        except Exception as e:
            print(organoid.organoid_id, organoid.well.well_id, organoid.well.plate.plate_id, e) #usually exception is that no nuc were detected so csv is empty. in this case, skip organoid
            continue 
        
        nuc_feat_df_list.append(m)


# if there are any nuclear features, concatenate and save csv
if not len(nuc_feat_df_list) == 0:
    nuc_df = pd.concat(nuc_feat_df_list, ignore_index=True, sort=False)
    nuc_df = nuc_df.sort_values(by=["hcs_experiment", "root_dir", "plate_id", "well_id", "org_label", "nuc_id", "channel_id"])
    nuc_df.to_csv(join(exp.get_experiment_dir(),"nuc_df.csv"), index=False) #saves csv
# Out:
# object_58 B03 day2p5 No columns to parse from file
# object_58 B03 day2p5 No columns to parse from file
# object_58 B03 day2p5 No columns to parse from file
# object_58 B03 day2p5 No columns to parse from file
# object_86 B03 day2p5 No columns to parse from file
# object_86 B03 day2p5 No columns to parse from file
# object_86 B03 day2p5 No columns to parse from file
# object_86 B03 day2p5 No columns to parse from file
# object_43 B03 day2p5 No columns to parse from file
# object_43 B03 day2p5 No columns to parse from file
# object_43 B03 day2p5 No columns to parse from file
# object_43 B03 day2p5 No columns to parse from file
# object_75 B03 day2p5 No columns to parse from file
# object_75 B03 day2p5 No columns to parse from file
# object_75 B03 day2p5 No columns to parse from file
# object_75 B03 day2p5 No columns to parse from file
# object_33 B03 day2p5 No columns to parse from file
# object_33 B03 day2p5 No columns to parse from file
# object_33 B03 day2p5 No columns to parse from file
# object_33 B03 day2p5 No columns to parse from file
# object_39 B03 day2p5 No columns to parse from file
# object_39 B03 day2p5 No columns to parse from file
# object_39 B03 day2p5 No columns to parse from file
# object_39 B03 day2p5 No columns to parse from file
# object_23 B03 day2p5 No columns to parse from file
# object_23 B03 day2p5 No columns to parse from file
# object_23 B03 day2p5 No columns to parse from file
# object_23 B03 day2p5 No columns to parse from file
# object_70 B03 day2p5 No columns to parse from file
# object_70 B03 day2p5 No columns to parse from file
# object_70 B03 day2p5 No columns to parse from file
# object_70 B03 day2p5 No columns to parse from file
# object_76 B03 day2p5 No columns to parse from file
# object_76 B03 day2p5 No columns to parse from file
# object_76 B03 day2p5 No columns to parse from file
# object_76 B03 day2p5 No columns to parse from file
# object_83 B03 day2p5 No columns to parse from file
# object_83 B03 day2p5 No columns to parse from file
# object_83 B03 day2p5 No columns to parse from file
# object_83 B03 day2p5 No columns to parse from file
# object_53 B03 day2p5 No columns to parse from file
# object_53 B03 day2p5 No columns to parse from file
# object_53 B03 day2p5 No columns to parse from file
# object_53 B03 day2p5 No columns to parse from file
# object_26 B03 day2p5 No columns to parse from file
# object_26 B03 day2p5 No columns to parse from file
# object_26 B03 day2p5 No columns to parse from file
# object_26 B03 day2p5 No columns to parse from file
# object_13 B05 day2p5 No columns to parse from file
# object_13 B05 day2p5 No columns to parse from file
# object_13 B05 day2p5 No columns to parse from file
# object_13 B05 day2p5 No columns to parse from file
# object_65 B05 day2p5 No columns to parse from file
# object_65 B05 day2p5 No columns to parse from file
# object_65 B05 day2p5 No columns to parse from file
# object_65 B05 day2p5 No columns to parse from file
# object_75 B05 day2p5 No columns to parse from file
# object_75 B05 day2p5 No columns to parse from file
# object_75 B05 day2p5 No columns to parse from file
# object_75 B05 day2p5 No columns to parse from file
# object_33 B05 day2p5 No columns to parse from file
# object_33 B05 day2p5 No columns to parse from file
# object_33 B05 day2p5 No columns to parse from file
# object_33 B05 day2p5 No columns to parse from file
# object_84 B05 day2p5 No columns to parse from file
# object_84 B05 day2p5 No columns to parse from file
# object_84 B05 day2p5 No columns to parse from file
# object_84 B05 day2p5 No columns to parse from file
# object_15 B05 day2p5 No columns to parse from file
# object_15 B05 day2p5 No columns to parse from file
# object_15 B05 day2p5 No columns to parse from file
# object_15 B05 day2p5 No columns to parse from file
# object_129 B05 day2p5 No columns to parse from file
# object_129 B05 day2p5 No columns to parse from file
# object_129 B05 day2p5 No columns to parse from file
# object_129 B05 day2p5 No columns to parse from file
# object_99 B05 day2p5 No columns to parse from file
# object_99 B05 day2p5 No columns to parse from file
# object_99 B05 day2p5 No columns to parse from file
# object_99 B05 day2p5 No columns to parse from file
# object_63 B05 day2p5 No columns to parse from file
# object_63 B05 day2p5 No columns to parse from file
# object_63 B05 day2p5 No columns to parse from file
# object_63 B05 day2p5 No columns to parse from file
# object_118 B05 day2p5 No columns to parse from file
# object_118 B05 day2p5 No columns to parse from file
# object_118 B05 day2p5 No columns to parse from file
# object_118 B05 day2p5 No columns to parse from file
# object_50 B05 day2p5 No columns to parse from file
# object_50 B05 day2p5 No columns to parse from file
# object_50 B05 day2p5 No columns to parse from file
# object_50 B05 day2p5 No columns to parse from file
# object_38 B05 day2p5 No columns to parse from file
# object_38 B05 day2p5 No columns to parse from file
# object_38 B05 day2p5 No columns to parse from file
# object_38 B05 day2p5 No columns to parse from file
# object_122 B05 day2p5 No columns to parse from file
# object_122 B05 day2p5 No columns to parse from file
# object_122 B05 day2p5 No columns to parse from file
# object_122 B05 day2p5 No columns to parse from file
# object_31 B05 day2p5 No columns to parse from file
# object_31 B05 day2p5 No columns to parse from file
# object_31 B05 day2p5 No columns to parse from file
# object_31 B05 day2p5 No columns to parse from file
# object_77 B05 day2p5 No columns to parse from file
# object_77 B05 day2p5 No columns to parse from file
# object_77 B05 day2p5 No columns to parse from file
# object_77 B05 day2p5 No columns to parse from file
# object_71 B05 day2p5 No columns to parse from file
# object_71 B05 day2p5 No columns to parse from file
# object_71 B05 day2p5 No columns to parse from file
# object_71 B05 day2p5 No columns to parse from file
# object_10 B05 day2p5 No columns to parse from file
# object_10 B05 day2p5 No columns to parse from file
# object_10 B05 day2p5 No columns to parse from file
# object_10 B05 day2p5 No columns to parse from file
# object_14 B05 day2p5 No columns to parse from file
# object_14 B05 day2p5 No columns to parse from file
# object_14 B05 day2p5 No columns to parse from file
# object_14 B05 day2p5 No columns to parse from file
# object_42 B05 day2p5 No columns to parse from file
# object_42 B05 day2p5 No columns to parse from file
# object_42 B05 day2p5 No columns to parse from file
# object_42 B05 day2p5 No columns to parse from file
# object_83 B05 day2p5 No columns to parse from file
# object_83 B05 day2p5 No columns to parse from file
# object_83 B05 day2p5 No columns to parse from file
# object_83 B05 day2p5 No columns to parse from file
# object_6 B05 day2p5 No columns to parse from file
# object_6 B05 day2p5 No columns to parse from file
# object_6 B05 day2p5 No columns to parse from file
# object_6 B05 day2p5 No columns to parse from file
# object_97 B05 day2p5 No columns to parse from file
# object_97 B05 day2p5 No columns to parse from file
# object_97 B05 day2p5 No columns to parse from file
# object_97 B05 day2p5 No columns to parse from file
# object_26 B05 day2p5 No columns to parse from file
# object_26 B05 day2p5 No columns to parse from file
# object_26 B05 day2p5 No columns to parse from file
# object_26 B05 day2p5 No columns to parse from file
# object_17 B04 day2p5 No columns to parse from file
# object_17 B04 day2p5 No columns to parse from file
# object_17 B04 day2p5 No columns to parse from file
# object_17 B04 day2p5 No columns to parse from file
# object_23 B04 day2p5 No columns to parse from file
# object_23 B04 day2p5 No columns to parse from file
# object_23 B04 day2p5 No columns to parse from file
# object_23 B04 day2p5 No columns to parse from file
# object_21 B04 day2p5 No columns to parse from file
# object_21 B04 day2p5 No columns to parse from file
# object_21 B04 day2p5 No columns to parse from file
# object_21 B04 day2p5 No columns to parse from file
# object_27 B04 day2p5 No columns to parse from file
# object_27 B04 day2p5 No columns to parse from file
# object_27 B04 day2p5 No columns to parse from file
# object_27 B04 day2p5 No columns to parse from file
# object_70 B04 day2p5 No columns to parse from file
# object_70 B04 day2p5 No columns to parse from file
# object_70 B04 day2p5 No columns to parse from file
# object_70 B04 day2p5 No columns to parse from file
# object_102 B04 day2p5 No columns to parse from file
# object_102 B04 day2p5 No columns to parse from file
# object_102 B04 day2p5 No columns to parse from file
# object_102 B04 day2p5 No columns to parse from file
# object_106 B04 day2p5 No columns to parse from file
# object_106 B04 day2p5 No columns to parse from file
# object_106 B04 day2p5 No columns to parse from file
# object_106 B04 day2p5 No columns to parse from file
# object_63 B04 day2p5 No columns to parse from file
# object_63 B04 day2p5 No columns to parse from file
# object_63 B04 day2p5 No columns to parse from file
# object_63 B04 day2p5 No columns to parse from file
# object_48 B04 day2p5 No columns to parse from file
# object_48 B04 day2p5 No columns to parse from file
# object_48 B04 day2p5 No columns to parse from file
# object_48 B04 day2p5 No columns to parse from file
# object_94 B04 day2p5 No columns to parse from file
# object_94 B04 day2p5 No columns to parse from file
# object_94 B04 day2p5 No columns to parse from file
# object_94 B04 day2p5 No columns to parse from file
# object_104 B04 day2p5 No columns to parse from file
# object_104 B04 day2p5 No columns to parse from file
# object_104 B04 day2p5 No columns to parse from file
# object_104 B04 day2p5 No columns to parse from file
# object_73 B04 day2p5 No columns to parse from file
# object_73 B04 day2p5 No columns to parse from file
# object_73 B04 day2p5 No columns to parse from file
# object_73 B04 day2p5 No columns to parse from file
# object_4 B04 day2p5 No columns to parse from file
# object_4 B04 day2p5 No columns to parse from file
# object_4 B04 day2p5 No columns to parse from file
# object_4 B04 day2p5 No columns to parse from file
# object_49 B06 day2p5 No columns to parse from file
# object_49 B06 day2p5 No columns to parse from file
# object_49 B06 day2p5 No columns to parse from file
# object_49 B06 day2p5 No columns to parse from file
# object_95 B06 day2p5 No columns to parse from file
# object_95 B06 day2p5 No columns to parse from file
# object_95 B06 day2p5 No columns to parse from file
# object_95 B06 day2p5 No columns to parse from file
# object_35 B06 day2p5 No columns to parse from file
# object_35 B06 day2p5 No columns to parse from file
# object_35 B06 day2p5 No columns to parse from file
# object_35 B06 day2p5 No columns to parse from file
# object_111 B06 day2p5 No columns to parse from file
# object_111 B06 day2p5 No columns to parse from file
# object_111 B06 day2p5 No columns to parse from file
# object_111 B06 day2p5 No columns to parse from file
# object_65 B06 day2p5 No columns to parse from file
# object_65 B06 day2p5 No columns to parse from file
# object_65 B06 day2p5 No columns to parse from file
# object_65 B06 day2p5 No columns to parse from file
# object_70 B06 day2p5 No columns to parse from file
# object_70 B06 day2p5 No columns to parse from file
# object_70 B06 day2p5 No columns to parse from file
# object_70 B06 day2p5 No columns to parse from file
# object_102 B06 day2p5 No columns to parse from file
# object_102 B06 day2p5 No columns to parse from file
# object_102 B06 day2p5 No columns to parse from file
# object_102 B06 day2p5 No columns to parse from file
# object_105 B06 day2p5 No columns to parse from file
# object_105 B06 day2p5 No columns to parse from file
# object_105 B06 day2p5 No columns to parse from file
# object_105 B06 day2p5 No columns to parse from file
# object_110 B06 day2p5 No columns to parse from file
# object_110 B06 day2p5 No columns to parse from file
# object_110 B06 day2p5 No columns to parse from file
# object_110 B06 day2p5 No columns to parse from file
# object_40 B06 day2p5 No columns to parse from file
# object_40 B06 day2p5 No columns to parse from file
# object_40 B06 day2p5 No columns to parse from file
# object_40 B06 day2p5 No columns to parse from file
# object_19 B06 day2p5 No columns to parse from file
# object_19 B06 day2p5 No columns to parse from file
# object_19 B06 day2p5 No columns to parse from file
# object_19 B06 day2p5 No columns to parse from file
# object_125 B06 day2p5 No columns to parse from file
# object_125 B06 day2p5 No columns to parse from file
# object_125 B06 day2p5 No columns to parse from file
# object_125 B06 day2p5 No columns to parse from file
# object_92 B06 day2p5 No columns to parse from file
# object_92 B06 day2p5 No columns to parse from file
# object_92 B06 day2p5 No columns to parse from file
# object_92 B06 day2p5 No columns to parse from file
# object_31 B06 day2p5 No columns to parse from file
# object_31 B06 day2p5 No columns to parse from file
# object_31 B06 day2p5 No columns to parse from file
# object_31 B06 day2p5 No columns to parse from file
# object_71 B06 day2p5 No columns to parse from file
# object_71 B06 day2p5 No columns to parse from file
# object_71 B06 day2p5 No columns to parse from file
# object_71 B06 day2p5 No columns to parse from file
# object_42 B06 day2p5 No columns to parse from file
# object_42 B06 day2p5 No columns to parse from file
# object_42 B06 day2p5 No columns to parse from file
# object_42 B06 day2p5 No columns to parse from file
# object_81 B06 day2p5 No columns to parse from file
# object_81 B06 day2p5 No columns to parse from file
# object_81 B06 day2p5 No columns to parse from file
# object_81 B06 day2p5 No columns to parse from file
# object_74 B03 day1p5 No columns to parse from file
# object_74 B03 day1p5 No columns to parse from file
# object_74 B03 day1p5 No columns to parse from file
# object_74 B03 day1p5 No columns to parse from file
# object_35 B03 day1p5 No columns to parse from file
# object_35 B03 day1p5 No columns to parse from file
# object_35 B03 day1p5 No columns to parse from file
# object_35 B03 day1p5 No columns to parse from file
# object_47 B03 day1p5 No columns to parse from file
# object_47 B03 day1p5 No columns to parse from file
# object_47 B03 day1p5 No columns to parse from file
# object_47 B03 day1p5 No columns to parse from file
# object_75 B03 day1p5 No columns to parse from file
# object_75 B03 day1p5 No columns to parse from file
# object_75 B03 day1p5 No columns to parse from file
# object_75 B03 day1p5 No columns to parse from file
# object_27 B03 day1p5 No columns to parse from file
# object_27 B03 day1p5 No columns to parse from file
# object_27 B03 day1p5 No columns to parse from file
# object_27 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_19 B03 day1p5 No columns to parse from file
# object_19 B03 day1p5 No columns to parse from file
# object_19 B03 day1p5 No columns to parse from file
# object_19 B03 day1p5 No columns to parse from file
# object_62 B03 day1p5 No columns to parse from file
# object_62 B03 day1p5 No columns to parse from file
# object_62 B03 day1p5 No columns to parse from file
# object_62 B03 day1p5 No columns to parse from file
# object_77 B03 day1p5 No columns to parse from file
# object_77 B03 day1p5 No columns to parse from file
# object_77 B03 day1p5 No columns to parse from file
# object_77 B03 day1p5 No columns to parse from file
# object_14 B03 day1p5 No columns to parse from file
# object_14 B03 day1p5 No columns to parse from file
# object_14 B03 day1p5 No columns to parse from file
# object_14 B03 day1p5 No columns to parse from file
# object_74 B05 day1p5 No columns to parse from file
# object_74 B05 day1p5 No columns to parse from file
# object_74 B05 day1p5 No columns to parse from file
# object_74 B05 day1p5 No columns to parse from file
# object_39 B05 day1p5 No columns to parse from file
# object_39 B05 day1p5 No columns to parse from file
# object_39 B05 day1p5 No columns to parse from file
# object_39 B05 day1p5 No columns to parse from file
# object_29 B05 day1p5 No columns to parse from file
# object_29 B05 day1p5 No columns to parse from file
# object_29 B05 day1p5 No columns to parse from file
# object_29 B05 day1p5 No columns to parse from file
# object_85 B05 day1p5 No columns to parse from file
# object_85 B05 day1p5 No columns to parse from file
# object_85 B05 day1p5 No columns to parse from file
# object_85 B05 day1p5 No columns to parse from file
# object_53 B05 day1p5 No columns to parse from file
# object_53 B05 day1p5 No columns to parse from file
# object_53 B05 day1p5 No columns to parse from file
# object_53 B05 day1p5 No columns to parse from file
# object_64 B05 day1p5 No columns to parse from file
# object_64 B05 day1p5 No columns to parse from file
# object_64 B05 day1p5 No columns to parse from file
# object_64 B05 day1p5 No columns to parse from file
# object_12 B04 day1p5 No columns to parse from file
# object_12 B04 day1p5 No columns to parse from file
# object_12 B04 day1p5 No columns to parse from file
# object_12 B04 day1p5 No columns to parse from file
# object_57 B04 day1p5 No columns to parse from file
# object_57 B04 day1p5 No columns to parse from file
# object_57 B04 day1p5 No columns to parse from file
# object_57 B04 day1p5 No columns to parse from file
# object_82 B04 day1p5 No columns to parse from file
# object_82 B04 day1p5 No columns to parse from file
# object_82 B04 day1p5 No columns to parse from file
# object_82 B04 day1p5 No columns to parse from file
# object_33 B04 day1p5 No columns to parse from file
# object_33 B04 day1p5 No columns to parse from file
# object_33 B04 day1p5 No columns to parse from file
# object_33 B04 day1p5 No columns to parse from file
# object_16 B04 day1p5 No columns to parse from file
# object_16 B04 day1p5 No columns to parse from file
# object_16 B04 day1p5 No columns to parse from file
# object_16 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_79 B06 day1p5 No columns to parse from file
# object_79 B06 day1p5 No columns to parse from file
# object_79 B06 day1p5 No columns to parse from file
# object_79 B06 day1p5 No columns to parse from file
# object_32 B06 day1p5 No columns to parse from file
# object_32 B06 day1p5 No columns to parse from file
# object_32 B06 day1p5 No columns to parse from file
# object_32 B06 day1p5 No columns to parse from file
# object_62 B06 day1p5 No columns to parse from file
# object_62 B06 day1p5 No columns to parse from file
# object_62 B06 day1p5 No columns to parse from file
# object_62 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_7 B03 day3p5 No columns to parse from file
# object_7 B03 day3p5 No columns to parse from file
# object_7 B03 day3p5 No columns to parse from file
# object_7 B03 day3p5 No columns to parse from file
# object_65 B05 day3p5 No columns to parse from file
# object_65 B05 day3p5 No columns to parse from file
# object_65 B05 day3p5 No columns to parse from file
# object_65 B05 day3p5 No columns to parse from file
# object_30 B05 day3p5 No columns to parse from file
# object_30 B05 day3p5 No columns to parse from file
# object_30 B05 day3p5 No columns to parse from file
# object_30 B05 day3p5 No columns to parse from file
# object_80 B04 day3p5 No columns to parse from file
# object_80 B04 day3p5 No columns to parse from file
# object_80 B04 day3p5 No columns to parse from file
# object_80 B04 day3p5 No columns to parse from file
# object_33 B04 day3p5 No columns to parse from file
# object_33 B04 day3p5 No columns to parse from file
# object_33 B04 day3p5 No columns to parse from file
# object_33 B04 day3p5 No columns to parse from file
# object_31 B04 day3p5 No columns to parse from file
# object_31 B04 day3p5 No columns to parse from file
# object_31 B04 day3p5 No columns to parse from file
# object_31 B04 day3p5 No columns to parse from file
# object_71 B04 day3p5 No columns to parse from file
# object_71 B04 day3p5 No columns to parse from file
# object_71 B04 day3p5 No columns to parse from file
# object_71 B04 day3p5 No columns to parse from file
# object_15 B06 day3p5 No columns to parse from file
# object_15 B06 day3p5 No columns to parse from file
# object_15 B06 day3p5 No columns to parse from file
# object_15 B06 day3p5 No columns to parse from file
# object_13 B03 day2 No columns to parse from file
# object_13 B03 day2 No columns to parse from file
# object_13 B03 day2 No columns to parse from file
# object_13 B03 day2 No columns to parse from file
# object_12 B03 day2 No columns to parse from file
# object_12 B03 day2 No columns to parse from file
# object_12 B03 day2 No columns to parse from file
# object_12 B03 day2 No columns to parse from file
# object_27 B03 day2 No columns to parse from file
# object_27 B03 day2 No columns to parse from file
# object_27 B03 day2 No columns to parse from file
# object_27 B03 day2 No columns to parse from file
# object_69 B03 day2 No columns to parse from file
# object_69 B03 day2 No columns to parse from file
# object_69 B03 day2 No columns to parse from file
# object_69 B03 day2 No columns to parse from file
# object_99 B03 day2 No columns to parse from file
# object_99 B03 day2 No columns to parse from file
# object_99 B03 day2 No columns to parse from file
# object_99 B03 day2 No columns to parse from file
# object_48 B03 day2 No columns to parse from file
# object_48 B03 day2 No columns to parse from file
# object_48 B03 day2 No columns to parse from file
# object_48 B03 day2 No columns to parse from file
# object_37 B03 day2 No columns to parse from file
# object_37 B03 day2 No columns to parse from file
# object_37 B03 day2 No columns to parse from file
# object_37 B03 day2 No columns to parse from file
# object_55 B05 day2 No columns to parse from file
# object_55 B05 day2 No columns to parse from file
# object_55 B05 day2 No columns to parse from file
# object_55 B05 day2 No columns to parse from file
# object_70 B05 day2 No columns to parse from file
# object_70 B05 day2 No columns to parse from file
# object_70 B05 day2 No columns to parse from file
# object_70 B05 day2 No columns to parse from file
# object_40 B05 day2 No columns to parse from file
# object_40 B05 day2 No columns to parse from file
# object_40 B05 day2 No columns to parse from file
# object_40 B05 day2 No columns to parse from file
# object_9 B05 day2 No columns to parse from file
# object_9 B05 day2 No columns to parse from file
# object_9 B05 day2 No columns to parse from file
# object_9 B05 day2 No columns to parse from file
# object_47 B04 day2 No columns to parse from file
# object_47 B04 day2 No columns to parse from file
# object_47 B04 day2 No columns to parse from file
# object_47 B04 day2 No columns to parse from file
# object_39 B04 day2 No columns to parse from file
# object_39 B04 day2 No columns to parse from file
# object_39 B04 day2 No columns to parse from file
# object_39 B04 day2 No columns to parse from file
# object_25 B04 day2 No columns to parse from file
# object_25 B04 day2 No columns to parse from file
# object_25 B04 day2 No columns to parse from file
# object_25 B04 day2 No columns to parse from file
# object_3 B04 day2 No columns to parse from file
# object_3 B04 day2 No columns to parse from file
# object_3 B04 day2 No columns to parse from file
# object_3 B04 day2 No columns to parse from file
# object_38 B04 day2 No columns to parse from file
# object_38 B04 day2 No columns to parse from file
# object_38 B04 day2 No columns to parse from file
# object_38 B04 day2 No columns to parse from file
# object_85 B04 day2 No columns to parse from file
# object_85 B04 day2 No columns to parse from file
# object_85 B04 day2 No columns to parse from file
# object_85 B04 day2 No columns to parse from file
# object_6 B04 day2 No columns to parse from file
# object_6 B04 day2 No columns to parse from file
# object_6 B04 day2 No columns to parse from file
# object_6 B04 day2 No columns to parse from file
# object_5 B04 day2 No columns to parse from file
# object_5 B04 day2 No columns to parse from file
# object_5 B04 day2 No columns to parse from file
# object_5 B04 day2 No columns to parse from file
# object_93 B06 day2 No columns to parse from file
# object_93 B06 day2 No columns to parse from file
# object_93 B06 day2 No columns to parse from file
# object_93 B06 day2 No columns to parse from file
# object_47 B06 day2 No columns to parse from file
# object_47 B06 day2 No columns to parse from file
# object_47 B06 day2 No columns to parse from file
# object_47 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_19 B06 day2 No columns to parse from file
# object_19 B06 day2 No columns to parse from file
# object_19 B06 day2 No columns to parse from file
# object_19 B06 day2 No columns to parse from file
# object_48 B06 day2 No columns to parse from file
# object_48 B06 day2 No columns to parse from file
# object_48 B06 day2 No columns to parse from file
# object_48 B06 day2 No columns to parse from file
# object_94 B06 day2 No columns to parse from file
# object_94 B06 day2 No columns to parse from file
# object_94 B06 day2 No columns to parse from file
# object_94 B06 day2 No columns to parse from file
# object_85 B06 day2 No columns to parse from file
# object_85 B06 day2 No columns to parse from file
# object_85 B06 day2 No columns to parse from file
# object_85 B06 day2 No columns to parse from file
# object_8 B06 day2 No columns to parse from file
# object_8 B06 day2 No columns to parse from file
# object_8 B06 day2 No columns to parse from file
# object_8 B06 day2 No columns to parse from file
# object_6 B06 day2 No columns to parse from file
# object_6 B06 day2 No columns to parse from file
# object_6 B06 day2 No columns to parse from file
# object_6 B06 day2 No columns to parse from file
# object_97 B06 day2 No columns to parse from file
# object_97 B06 day2 No columns to parse from file
# object_97 B06 day2 No columns to parse from file
# object_97 B06 day2 No columns to parse from file
# object_46 B03 day3 No columns to parse from file
# object_46 B03 day3 No columns to parse from file
# object_46 B03 day3 No columns to parse from file
# object_46 B03 day3 No columns to parse from file
# object_62 B03 day3 No columns to parse from file
# object_62 B03 day3 No columns to parse from file
# object_62 B03 day3 No columns to parse from file
# object_62 B03 day3 No columns to parse from file
# object_38 B03 day3 No columns to parse from file
# object_38 B03 day3 No columns to parse from file
# object_38 B03 day3 No columns to parse from file
# object_38 B03 day3 No columns to parse from file
# object_64 B03 day3 No columns to parse from file
# object_64 B03 day3 No columns to parse from file
# object_64 B03 day3 No columns to parse from file
# object_64 B03 day3 No columns to parse from file
# object_13 B05 day3 No columns to parse from file
# object_13 B05 day3 No columns to parse from file
# object_13 B05 day3 No columns to parse from file
# object_13 B05 day3 No columns to parse from file
# object_12 B05 day3 No columns to parse from file
# object_12 B05 day3 No columns to parse from file
# object_12 B05 day3 No columns to parse from file
# object_12 B05 day3 No columns to parse from file
# object_93 B05 day3 No columns to parse from file
# object_93 B05 day3 No columns to parse from file
# object_93 B05 day3 No columns to parse from file
# object_93 B05 day3 No columns to parse from file
# object_65 B05 day3 No columns to parse from file
# object_65 B05 day3 No columns to parse from file
# object_65 B05 day3 No columns to parse from file
# object_65 B05 day3 No columns to parse from file
# object_91 B05 day3 No columns to parse from file
# object_91 B05 day3 No columns to parse from file
# object_91 B05 day3 No columns to parse from file
# object_91 B05 day3 No columns to parse from file
# object_33 B05 day3 No columns to parse from file
# object_33 B05 day3 No columns to parse from file
# object_33 B05 day3 No columns to parse from file
# object_33 B05 day3 No columns to parse from file
# object_36 B05 day3 No columns to parse from file
# object_36 B05 day3 No columns to parse from file
# object_36 B05 day3 No columns to parse from file
# object_36 B05 day3 No columns to parse from file
# object_40 B05 day3 No columns to parse from file
# object_40 B05 day3 No columns to parse from file
# object_40 B05 day3 No columns to parse from file
# object_40 B05 day3 No columns to parse from file
# object_1 B05 day3 No columns to parse from file
# object_1 B05 day3 No columns to parse from file
# object_1 B05 day3 No columns to parse from file
# object_1 B05 day3 No columns to parse from file
# object_10 B05 day3 No columns to parse from file
# object_10 B05 day3 No columns to parse from file
# object_10 B05 day3 No columns to parse from file
# object_10 B05 day3 No columns to parse from file
# object_87 B05 day3 No columns to parse from file
# object_87 B05 day3 No columns to parse from file
# object_87 B05 day3 No columns to parse from file
# object_87 B05 day3 No columns to parse from file
# object_13 B04 day3 No columns to parse from file
# object_13 B04 day3 No columns to parse from file
# object_13 B04 day3 No columns to parse from file
# object_13 B04 day3 No columns to parse from file
# object_74 B04 day3 No columns to parse from file
# object_74 B04 day3 No columns to parse from file
# object_74 B04 day3 No columns to parse from file
# object_74 B04 day3 No columns to parse from file
# object_65 B04 day3 No columns to parse from file
# object_65 B04 day3 No columns to parse from file
# object_65 B04 day3 No columns to parse from file
# object_65 B04 day3 No columns to parse from file
# object_82 B04 day3 No columns to parse from file
# object_82 B04 day3 No columns to parse from file
# object_82 B04 day3 No columns to parse from file
# object_82 B04 day3 No columns to parse from file
# object_17 B04 day3 No columns to parse from file
# object_17 B04 day3 No columns to parse from file
# object_17 B04 day3 No columns to parse from file
# object_17 B04 day3 No columns to parse from file
# object_33 B04 day3 No columns to parse from file
# object_33 B04 day3 No columns to parse from file
# object_33 B04 day3 No columns to parse from file
# object_33 B04 day3 No columns to parse from file
# object_23 B04 day3 No columns to parse from file
# object_23 B04 day3 No columns to parse from file
# object_23 B04 day3 No columns to parse from file
# object_23 B04 day3 No columns to parse from file
# object_70 B04 day3 No columns to parse from file
# object_70 B04 day3 No columns to parse from file
# object_70 B04 day3 No columns to parse from file
# object_70 B04 day3 No columns to parse from file
# object_20 B04 day3 No columns to parse from file
# object_20 B04 day3 No columns to parse from file
# object_20 B04 day3 No columns to parse from file
# object_20 B04 day3 No columns to parse from file
# object_63 B04 day3 No columns to parse from file
# object_63 B04 day3 No columns to parse from file
# object_63 B04 day3 No columns to parse from file
# object_63 B04 day3 No columns to parse from file
# object_76 B04 day3 No columns to parse from file
# object_76 B04 day3 No columns to parse from file
# object_76 B04 day3 No columns to parse from file
# object_76 B04 day3 No columns to parse from file
# object_59 B04 day3 No columns to parse from file
# object_59 B04 day3 No columns to parse from file
# object_59 B04 day3 No columns to parse from file
# object_59 B04 day3 No columns to parse from file
# object_24 B04 day3 No columns to parse from file
# object_24 B04 day3 No columns to parse from file
# object_24 B04 day3 No columns to parse from file
# object_24 B04 day3 No columns to parse from file
# object_73 B04 day3 No columns to parse from file
# object_73 B04 day3 No columns to parse from file
# object_73 B04 day3 No columns to parse from file
# object_73 B04 day3 No columns to parse from file
# object_26 B04 day3 No columns to parse from file
# object_26 B04 day3 No columns to parse from file
# object_26 B04 day3 No columns to parse from file
# object_26 B04 day3 No columns to parse from file
# object_13 B06 day3 No columns to parse from file
# object_13 B06 day3 No columns to parse from file
# object_13 B06 day3 No columns to parse from file
# object_13 B06 day3 No columns to parse from file
# object_84 B06 day3 No columns to parse from file
# object_84 B06 day3 No columns to parse from file
# object_84 B06 day3 No columns to parse from file
# object_84 B06 day3 No columns to parse from file
# object_27 B06 day3 No columns to parse from file
# object_27 B06 day3 No columns to parse from file
# object_27 B06 day3 No columns to parse from file
# object_27 B06 day3 No columns to parse from file
# object_22 B06 day3 No columns to parse from file
# object_22 B06 day3 No columns to parse from file
# object_22 B06 day3 No columns to parse from file
# object_22 B06 day3 No columns to parse from file
# object_8 B06 day3 No columns to parse from file
# object_8 B06 day3 No columns to parse from file
# object_8 B06 day3 No columns to parse from file
# object_8 B06 day3 No columns to parse from file
# object_80 B03 day4 No columns to parse from file
# object_80 B03 day4 No columns to parse from file
# object_80 B03 day4 No columns to parse from file
# object_80 B03 day4 No columns to parse from file
# object_46 B03 day4 No columns to parse from file
# object_46 B03 day4 No columns to parse from file
# object_46 B03 day4 No columns to parse from file
# object_46 B03 day4 No columns to parse from file
# object_82 B03 day4 No columns to parse from file
# object_82 B03 day4 No columns to parse from file
# object_82 B03 day4 No columns to parse from file
# object_82 B03 day4 No columns to parse from file
# object_11 B03 day4 No columns to parse from file
# object_11 B03 day4 No columns to parse from file
# object_11 B03 day4 No columns to parse from file
# object_11 B03 day4 No columns to parse from file
# object_75 B03 day4 No columns to parse from file
# object_75 B03 day4 No columns to parse from file
# object_75 B03 day4 No columns to parse from file
# object_75 B03 day4 No columns to parse from file
# object_70 B03 day4 No columns to parse from file
# object_70 B03 day4 No columns to parse from file
# object_70 B03 day4 No columns to parse from file
# object_70 B03 day4 No columns to parse from file
# object_45 B03 day4 No columns to parse from file
# object_45 B03 day4 No columns to parse from file
# object_45 B03 day4 No columns to parse from file
# object_45 B03 day4 No columns to parse from file
# object_63 B03 day4 No columns to parse from file
# object_63 B03 day4 No columns to parse from file
# object_63 B03 day4 No columns to parse from file
# object_63 B03 day4 No columns to parse from file
# object_50 B03 day4 No columns to parse from file
# object_50 B03 day4 No columns to parse from file
# object_50 B03 day4 No columns to parse from file
# object_50 B03 day4 No columns to parse from file
# object_1 B03 day4 No columns to parse from file
# object_1 B03 day4 No columns to parse from file
# object_1 B03 day4 No columns to parse from file
# object_1 B03 day4 No columns to parse from file
# object_73 B03 day4 No columns to parse from file
# object_73 B03 day4 No columns to parse from file
# object_73 B03 day4 No columns to parse from file
# object_73 B03 day4 No columns to parse from file
# object_67 B03 day4 No columns to parse from file
# object_67 B03 day4 No columns to parse from file
# object_67 B03 day4 No columns to parse from file
# object_67 B03 day4 No columns to parse from file
# object_9 B03 day4 No columns to parse from file
# object_9 B03 day4 No columns to parse from file
# object_9 B03 day4 No columns to parse from file
# object_9 B03 day4 No columns to parse from file
# object_6 B03 day4 No columns to parse from file
# object_6 B03 day4 No columns to parse from file
# object_6 B03 day4 No columns to parse from file
# object_6 B03 day4 No columns to parse from file
# object_57 B05 day4 No columns to parse from file
# object_57 B05 day4 No columns to parse from file
# object_57 B05 day4 No columns to parse from file
# object_57 B05 day4 No columns to parse from file
# object_79 B05 day4 No columns to parse from file
# object_79 B05 day4 No columns to parse from file
# object_79 B05 day4 No columns to parse from file
# object_79 B05 day4 No columns to parse from file
# object_11 B05 day4 No columns to parse from file
# object_11 B05 day4 No columns to parse from file
# object_11 B05 day4 No columns to parse from file
# object_11 B05 day4 No columns to parse from file
# object_84 B05 day4 No columns to parse from file
# object_84 B05 day4 No columns to parse from file
# object_84 B05 day4 No columns to parse from file
# object_84 B05 day4 No columns to parse from file
# object_70 B05 day4 No columns to parse from file
# object_70 B05 day4 No columns to parse from file
# object_70 B05 day4 No columns to parse from file
# object_70 B05 day4 No columns to parse from file
# object_36 B05 day4 No columns to parse from file
# object_36 B05 day4 No columns to parse from file
# object_36 B05 day4 No columns to parse from file
# object_36 B05 day4 No columns to parse from file
# object_66 B05 day4 No columns to parse from file
# object_66 B05 day4 No columns to parse from file
# object_66 B05 day4 No columns to parse from file
# object_66 B05 day4 No columns to parse from file
# object_20 B05 day4 No columns to parse from file
# object_20 B05 day4 No columns to parse from file
# object_20 B05 day4 No columns to parse from file
# object_20 B05 day4 No columns to parse from file
# object_45 B05 day4 No columns to parse from file
# object_45 B05 day4 No columns to parse from file
# object_45 B05 day4 No columns to parse from file
# object_45 B05 day4 No columns to parse from file
# object_77 B05 day4 No columns to parse from file
# object_77 B05 day4 No columns to parse from file
# object_77 B05 day4 No columns to parse from file
# object_77 B05 day4 No columns to parse from file
# object_71 B05 day4 No columns to parse from file
# object_71 B05 day4 No columns to parse from file
# object_71 B05 day4 No columns to parse from file
# object_71 B05 day4 No columns to parse from file
# object_9 B05 day4 No columns to parse from file
# object_9 B05 day4 No columns to parse from file
# object_9 B05 day4 No columns to parse from file
# object_9 B05 day4 No columns to parse from file
# object_7 B05 day4 No columns to parse from file
# object_7 B05 day4 No columns to parse from file
# object_7 B05 day4 No columns to parse from file
# object_7 B05 day4 No columns to parse from file
# object_53 B05 day4 No columns to parse from file
# object_53 B05 day4 No columns to parse from file
# object_53 B05 day4 No columns to parse from file
# object_53 B05 day4 No columns to parse from file
# object_68 B05 day4 No columns to parse from file
# object_68 B05 day4 No columns to parse from file
# object_68 B05 day4 No columns to parse from file
# object_68 B05 day4 No columns to parse from file
# object_37 B05 day4 No columns to parse from file
# object_37 B05 day4 No columns to parse from file
# object_37 B05 day4 No columns to parse from file
# object_37 B05 day4 No columns to parse from file
# object_60 B04 day4 No columns to parse from file
# object_60 B04 day4 No columns to parse from file
# object_60 B04 day4 No columns to parse from file
# object_60 B04 day4 No columns to parse from file
# object_41 B04 day4 No columns to parse from file
# object_41 B04 day4 No columns to parse from file
# object_41 B04 day4 No columns to parse from file
# object_41 B04 day4 No columns to parse from file
# object_15 B04 day4 No columns to parse from file
# object_15 B04 day4 No columns to parse from file
# object_15 B04 day4 No columns to parse from file
# object_15 B04 day4 No columns to parse from file
# object_2 B04 day4 No columns to parse from file
# object_2 B04 day4 No columns to parse from file
# object_2 B04 day4 No columns to parse from file
# object_2 B04 day4 No columns to parse from file
# object_46 B06 day4 No columns to parse from file
# object_46 B06 day4 No columns to parse from file
# object_46 B06 day4 No columns to parse from file
# object_46 B06 day4 No columns to parse from file
# object_61 B06 day4 No columns to parse from file
# object_61 B06 day4 No columns to parse from file
# object_61 B06 day4 No columns to parse from file
# object_61 B06 day4 No columns to parse from file
# object_69 B06 day4 No columns to parse from file
# object_69 B06 day4 No columns to parse from file
# object_69 B06 day4 No columns to parse from file
# object_69 B06 day4 No columns to parse from file
# object_10 B06 day4 No columns to parse from file
# object_10 B06 day4 No columns to parse from file
# object_10 B06 day4 No columns to parse from file
# object_10 B06 day4 No columns to parse from file

# %% [markdown]
# ## Merge membrane features into single df

# %%
#pool together regionprops_mem files
exp.only_iterate_over_wells(False)
exp.reset_iterator()

#create list of dataframes from all well and organoids
mem_feat_df_list =[] #length of list is #plates * # wells * #channels * # organoids/well

for organoid in exp:
    memMeasurements = [k for k,v in organoid.measurements.items() if k.startswith('regionprops_mem')]
    
    # if no nuclear feature extraction in folder, skip
    if not memMeasurements:
        continue
        
    for meas_name in memMeasurements:
        try:
            m = organoid.get_measurement(meas_name)
        
        except Exception as e:
            print(organoid.organoid_id, organoid.well.well_id, organoid.well.plate.plate_id, e) #usually exception is that no nuc were detected so csv is empty. in this case, skip organoid
            continue 
        
        mem_feat_df_list.append(m)

# if there are any nuclear features, concatenate and save csv
if not len(mem_feat_df_list) == 0:
    mem_df = pd.concat(mem_feat_df_list, ignore_index=True, sort=False)
    mem_df = mem_df.sort_values(by=["hcs_experiment", "root_dir", "plate_id", "well_id", "org_label", "mem_id", "channel_id"])
    mem_df.to_csv(join(exp.get_experiment_dir(),"mem_df.csv"), index=False) #saves csv
# Out:
# object_26 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_38 B05 day2 No columns to parse from file
# object_38 B05 day2 No columns to parse from file
# object_38 B05 day2 No columns to parse from file
# object_38 B05 day2 No columns to parse from file
# object_90 B04 day2 No columns to parse from file
# object_90 B04 day2 No columns to parse from file
# object_90 B04 day2 No columns to parse from file
# object_90 B04 day2 No columns to parse from file
# object_48 B04 day2 No columns to parse from file
# object_48 B04 day2 No columns to parse from file
# object_48 B04 day2 No columns to parse from file
# object_48 B04 day2 No columns to parse from file
# object_76 B04 day2 No columns to parse from file
# object_76 B04 day2 No columns to parse from file
# object_76 B04 day2 No columns to parse from file
# object_76 B04 day2 No columns to parse from file

# %% [markdown]
# ## Link together nuclei and cells

# %%
# #pool together regionprops_org files
# exp.only_iterate_over_wells(False)
# exp.reset_iterator()

# #create list of dataframes from all well and organoids
# cell_feat_df_list =[] #length of list is #plates * # wells * # organoids/well

# for organoid in exp:
#     nucMeasurements = [k for k,v in organoid.measurements.items() if k.startswith('regionprops_nuc')]
#     memMeasurements = [k for k,v in organoid.measurements.items() if k.startswith('regionprops_mem')]
#     linkMeasurement = [k for k,v in organoid.measurements.items() if k.startswith('linking_nuc_to_mem')]
    
#     # if no nuclear or membrane feature extraction in folder, skip. linking file must be unique
#     if not nucMeasurements:
#         continue
#     if not memMeasurements:
#         continue
#     if not len(linkMeasurement) == 1:
#         continue
    
#     linking = organoid.get_measurement('linking_nuc_to_mem')
#     linking_dict = linking.set_index('nuc_id').T.to_dict('index')['mem_id'] #nuc id is key, membrane id is value
        
#     for meas_name in nucMeasurements:
#         channel = meas_name[-3:]
        
#         try:
#             nuc = organoid.get_measurement(meas_name)
#         except Exception as e:
#             print(organoid.organoid_id, organoid.well.well_id, organoid.well.plate.plate_id, e) #usually exception is that no nuc were detected so csv is empty. in this case, skip organoid
#             continue 
        
#         try:
#             mem = organoid.get_measurement('regionprops_mem_' + channel)
#         except Exception as e:
#             print(organoid.organoid_id, organoid.well.well_id, organoid.well.plate.plate_id, e) #usually exception is that no nuc were detected so csv is empty. in this case, skip organoid
#             continue 
            
#         #select nuclei that are matched to a membrane
#         nuc_filt = nuc.loc[nuc['nuc_id'].isin(linking_dict.keys()), :].copy(deep=True)
#         #select membranes that are matched to a nucleus
#         mem_filt = mem.loc[mem['mem_id'].isin(linking_dict.values()), :]
#         #add column to nuc frame that includes matched membrane id
#         nuc_filt['mem_id'] = nuc_filt['nuc_id'].map(linking_dict)
        
#         #load matching cell file
#         cell = pd.merge(nuc_filt, mem_filt, how="left", on=["hcs_experiment", "root_dir", "plate_id", "well_id", "channel_id", "organoid_id", "org_label", "mem_id"], suffixes=('_nuc', '_mem'))
        
#         #append to list of dataframes
#         cell_feat_df_list.append(cell)
        
# # if there are cell features, concatenate and save csv
# if not len(cell_feat_df_list) == 0:
#     cell_df = pd.concat(cell_feat_df_list, ignore_index=True, sort=False)
#     cell_df = cell_df.sort_values(by=["hcs_experiment", "root_dir", "plate_id", "well_id", "org_label", "nuc_id", "channel_id"])
#     cell_df.to_csv(join(exp.get_experiment_dir(),"cell_df.csv"), index=False) #saves csv
# Out:
# object_67 B04 day2p5 No columns to parse from file
# object_67 B04 day2p5 No columns to parse from file
# object_67 B04 day2p5 No columns to parse from file
# object_67 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_66 B06 day2p5 No columns to parse from file
# object_66 B06 day2p5 No columns to parse from file
# object_66 B06 day2p5 No columns to parse from file
# object_66 B06 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_24 B03 day1p5 No columns to parse from file
# object_24 B03 day1p5 No columns to parse from file
# object_24 B03 day1p5 No columns to parse from file
# object_24 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_88 B05 day1p5 No columns to parse from file
# object_88 B05 day1p5 No columns to parse from file
# object_88 B05 day1p5 No columns to parse from file
# object_88 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_65 B06 day1p5 No columns to parse from file
# object_65 B06 day1p5 No columns to parse from file
# object_65 B06 day1p5 No columns to parse from file
# object_65 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_43 B06 day1p5 No columns to parse from file
# object_43 B06 day1p5 No columns to parse from file
# object_43 B06 day1p5 No columns to parse from file
# object_43 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_91 B04 day3p5 No columns to parse from file
# object_91 B04 day3p5 No columns to parse from file
# object_91 B04 day3p5 No columns to parse from file
# object_91 B04 day3p5 No columns to parse from file
# object_22 B06 day3p5 No columns to parse from file
# object_22 B06 day3p5 No columns to parse from file
# object_22 B06 day3p5 No columns to parse from file
# object_22 B06 day3p5 No columns to parse from file
# object_73 B03 day3p5 No columns to parse from file
# object_73 B03 day3p5 No columns to parse from file
# object_73 B03 day3p5 No columns to parse from file
# object_73 B03 day3p5 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_96734/786554895.py in <module>
#      26
#      27         try:
# ---> 28             nuc = organoid.get_measurement(meas_name)
#      29         except Exception as e:
#      30             print(organoid.organoid_id, organoid.well.well_id, organoid.well.plate.plate_id, e) #usually exception is that no nuc were detected so csv is empty. in this case, skip organoid
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/faim_hcs/records/DefaultRecord.py in get_measurement(self, name)
#      55         if name in self.measurements.keys():
#      56             location = self._get_source_file_location(self.measurements[name])
# ---> 57             return pd.read_csv(location)
#      58         else:
#      59             self.logger.warning(
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1057             new_rows = len(index)
#    1058
# -> 1059         df = DataFrame(col_dict, columns=columns, index=index)
#    1060
#    1061         self._currow += new_rows
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     414         from pandas.core.series import Series
#     415
# --> 416         arrays = Series(data, index=columns, dtype=object)
#     417         data_names = arrays.index
#     418         missing = arrays.isna()
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     403                 data = data._mgr
#     404             elif is_dict_like(data):
# --> 405                 data, index = self._init_dict(data, index, dtype)
#     406                 dtype = None
#     407                 copy = False
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/core/series.py in _init_dict(self, data, index, dtype)
#     495             index=keys,  # type: ignore[arg-type]
#     496             dtype=dtype,
# --> 497             dtype_if_empty=np.float64,
#     498         )
#     499
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/core/construction.py in create_series_with_explicit_dtype(data, index, dtype, name, copy, fastpath, dtype_if_empty)
#     833         dtype = dtype_if_empty
#     834     return Series(
# --> 835         data=data, index=index, dtype=dtype, name=name, copy=copy, fastpath=fastpath
#     836     )
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     366
#     367             if index is not None:
# --> 368                 index = ensure_index(index)
#     369
#     370             if data is None:
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    6334     else:
#    6335
# -> 6336         return Index(index_like, copy=copy)
#    6337
#    6338
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     493
#     494             subarr = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
# --> 495             return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#     496
#     497     @classmethod
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     460
#     461                 if dtype is None:
# --> 462                     arr = _maybe_cast_data_without_dtype(arr)
#     463                     dtype = arr.dtype
#     464
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/core/indexes/base.py in _maybe_cast_data_without_dtype(subarr)
#    6415         convert_period=True,
#    6416         convert_interval=True,
# -> 6417         dtype_if_all_nat=np.dtype("datetime64[ns]"),
#    6418     )
#    6419     if result.dtype.kind in ["b", "c"]:
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_objects()
#
# /tungstenfs/scratch/gliberal/Code/user-code/repinico/Python/venvs/miniconda3/envs/featX/lib/python3.7/site-packages/numpy/core/numeric.py in full(shape, fill_value, dtype, order, like)
#     287
#     288
# --> 289 @set_array_function_like_doc
#     290 @set_module('numpy')
#     291 def full(shape, fill_value, dtype=None, order='C', *, like=None):
#
# KeyboardInterrupt:

# %%
#pool together regionprops_org files
exp.only_iterate_over_wells(False)
exp.reset_iterator()

#create list of dataframes from all well and organoids
cell_feat_df_list =[] #length of list is #plates * # wells * # organoids/well

for organoid in exp:
    nucMeasurements = [k for k,v in organoid.measurements.items() if k.startswith('regionprops_nuc')]
    memMeasurements = [k for k,v in organoid.measurements.items() if k.startswith('regionprops_mem')]
    linkMeasurement = [k for k,v in organoid.measurements.items() if k.startswith('linking_nuc_to_mem')]
    
    # if no nuclear or membrane feature extraction in folder, skip. linking file must be unique
    if not nucMeasurements:
        continue
    if not memMeasurements:
        continue
    if not len(linkMeasurement) == 1:
        continue
    
    linking = organoid.get_measurement('linking_nuc_to_mem')
    linking_dict = linking.set_index('mem_id').T.to_dict('index')['nuc_id'] #mem id is key, nuc id is value
        
    for meas_name in nucMeasurements:
        channel = meas_name[-3:]
        
        try:
            nuc = organoid.get_measurement(meas_name)
        except Exception as e:
            print(organoid.organoid_id, organoid.well.well_id, organoid.well.plate.plate_id, e) #usually exception is that no nuc were detected so csv is empty. in this case, skip organoid
            continue 
        
        try:
            mem = organoid.get_measurement('regionprops_mem_' + channel)
        except Exception as e:
            print(organoid.organoid_id, organoid.well.well_id, organoid.well.plate.plate_id, e) #usually exception is that no nuc were detected so csv is empty. in this case, skip organoid
            continue 
            
        #select nuclei that are matched to a membrane
        nuc_filt = nuc.loc[nuc['nuc_id'].isin(linking_dict.values()), :].copy(deep=True)
        nuc_filt= nuc_filt.rename(columns={"segmentation_nuc": "segmentation"})
        #select membranes that are matched to a nucleus
        mem_filt = mem.loc[mem['mem_id'].isin(linking_dict.keys()), :].copy(deep=True)
        mem_filt= mem_filt.rename(columns={"segmentation_mem": "segmentation"})

        
        #add column to nuc frame that includes nuc id
        nuc_filt['nuc_id_linked'] = nuc_filt['nuc_id'].astype(int)
        
        #add column to mem frame that includes matched nuc id
        mem_filt['nuc_id_linked'] = mem_filt['mem_id'].map(linking_dict).astype(int)
        
        
        #load matching cell file
        cell = pd.concat([nuc_filt, mem_filt], ignore_index=True)
        #append to list of dataframes
        cell_feat_df_list.append(cell)
        
# if there are cell features, concatenate and save csv
if not len(cell_feat_df_list) == 0:
    cell_df = pd.concat(cell_feat_df_list, ignore_index=True, sort=False)
    
    cell_df = cell_df.reset_index(drop=True)
    cols_to_move = ["hcs_experiment", "root_dir","plate_id","well_id", "org_label", "nuc_id_linked", "channel_id", "nuc_id", "mem_id"]
    cell_df = cell_df[cols_to_move + [col for col in cell_df.columns if col not in cols_to_move]]
    cell_df = cell_df.sort_values(by=["hcs_experiment", "root_dir", "plate_id", "well_id", "org_label", "nuc_id_linked", "channel_id"])

    cell_df.to_csv(join(exp.get_experiment_dir(),"cell_df.csv"), index=False) #saves csv
# Out:
# object_67 B04 day2p5 No columns to parse from file
# object_67 B04 day2p5 No columns to parse from file
# object_67 B04 day2p5 No columns to parse from file
# object_67 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_26 B04 day2p5 No columns to parse from file
# object_66 B06 day2p5 No columns to parse from file
# object_66 B06 day2p5 No columns to parse from file
# object_66 B06 day2p5 No columns to parse from file
# object_66 B06 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_77 B03 day2p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_57 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_60 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_21 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_72 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_104 B03 day1p5 No columns to parse from file
# object_24 B03 day1p5 No columns to parse from file
# object_24 B03 day1p5 No columns to parse from file
# object_24 B03 day1p5 No columns to parse from file
# object_24 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_26 B03 day1p5 No columns to parse from file
# object_88 B05 day1p5 No columns to parse from file
# object_88 B05 day1p5 No columns to parse from file
# object_88 B05 day1p5 No columns to parse from file
# object_88 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_28 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_8 B05 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_93 B06 day1p5 No columns to parse from file
# object_65 B06 day1p5 No columns to parse from file
# object_65 B06 day1p5 No columns to parse from file
# object_65 B06 day1p5 No columns to parse from file
# object_65 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_17 B06 day1p5 No columns to parse from file
# object_43 B06 day1p5 No columns to parse from file
# object_43 B06 day1p5 No columns to parse from file
# object_43 B06 day1p5 No columns to parse from file
# object_43 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_41 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_98 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_15 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_114 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_94 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_88 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_44 B06 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_69 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_88 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_24 B04 day1p5 No columns to parse from file
# object_91 B04 day3p5 No columns to parse from file
# object_91 B04 day3p5 No columns to parse from file
# object_91 B04 day3p5 No columns to parse from file
# object_91 B04 day3p5 No columns to parse from file
# object_22 B06 day3p5 No columns to parse from file
# object_22 B06 day3p5 No columns to parse from file
# object_22 B06 day3p5 No columns to parse from file
# object_22 B06 day3p5 No columns to parse from file
# object_73 B03 day3p5 No columns to parse from file
# object_73 B03 day3p5 No columns to parse from file
# object_73 B03 day3p5 No columns to parse from file
# object_73 B03 day3p5 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_49 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_107 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_101 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_90 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_62 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_56 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_104 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_22 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_53 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_68 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_5 B03 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_116 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_27 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_106 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_73 B06 day2 No columns to parse from file
# object_38 B05 day2 No columns to parse from file
# object_38 B05 day2 No columns to parse from file
# object_38 B05 day2 No columns to parse from file
# object_38 B05 day2 No columns to parse from file
# object_90 B04 day2 No columns to parse from file
# object_90 B04 day2 No columns to parse from file
# object_90 B04 day2 No columns to parse from file
# object_90 B04 day2 No columns to parse from file
# object_48 B04 day2 No columns to parse from file
# object_48 B04 day2 No columns to parse from file
# object_48 B04 day2 No columns to parse from file
# object_48 B04 day2 No columns to parse from file
# object_76 B04 day2 No columns to parse from file
# object_76 B04 day2 No columns to parse from file
# object_76 B04 day2 No columns to parse from file
# object_76 B04 day2 No columns to parse from file
# object_46 B03 day3 No columns to parse from file
# object_46 B03 day3 No columns to parse from file
# object_46 B03 day3 No columns to parse from file
# object_46 B03 day3 No columns to parse from file
# object_24 B03 day3 No columns to parse from file
# object_24 B03 day3 No columns to parse from file
# object_24 B03 day3 No columns to parse from file
# object_24 B03 day3 No columns to parse from file
# object_47 B05 day4 No columns to parse from file
# object_47 B05 day4 No columns to parse from file
# object_47 B05 day4 No columns to parse from file
# object_47 B05 day4 No columns to parse from file
# object_20 B05 day4 No columns to parse from file
# object_20 B05 day4 No columns to parse from file
# object_20 B05 day4 No columns to parse from file
# object_20 B05 day4 No columns to parse from file
# object_7 B03 day4 No columns to parse from file
# object_7 B03 day4 No columns to parse from file
# object_7 B03 day4 No columns to parse from file
# object_7 B03 day4 No columns to parse from file

# %%
cell_df.head()
# Out:
#       hcs_experiment                                           root_dir  \
# 0  20220507GCPLEX_R0  /tungstenfs/scratch/gliberal/Users/repinico/Yo...
# 1  20220507GCPLEX_R0  /tungstenfs/scratch/gliberal/Users/repinico/Yo...
# 2  20220507GCPLEX_R0  /tungstenfs/scratch/gliberal/Users/repinico/Yo...
# 3  20220507GCPLEX_R0  /tungstenfs/scratch/gliberal/Users/repinico/Yo...
# 4  20220507GCPLEX_R0  /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#
#   plate_id well_id  org_label  nuc_id_linked channel_id  nuc_id  mem_id  \
# 0   day1p5     B03          1            1.0        C01     1.0     NaN
# 1   day1p5     B03          1            1.0        C01     NaN     2.0
# 2   day1p5     B03          1            1.0        C02     1.0     NaN
# 3   day1p5     B03          1            1.0        C02     NaN     2.0
# 4   day1p5     B03          1            1.0        C03     1.0     NaN
#
#   object_type organoid_id                                   segmentation_nuc  \
# 0     nucleus    object_1  day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...
# 1    membrane    object_1                                                NaN
# 2     nucleus    object_1  day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...
# 3    membrane    object_1                                                NaN
# 4     nucleus    object_1  day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...
#
#                                        intensity_img  x_pos_vox  y_pos_vox  \
# 0  day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...  46.907661  52.165490
# 1  day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...  47.293158  51.441142
# 2  day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...  46.907661  52.165490
# 3  day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...  47.293158  51.441142
# 4  day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...  46.907661  52.165490
#
#    z_pos_vox  volume_pix  mean_intensity  max_intensity  min_intensity  \
# 0  87.931539       63321      714.495760         1581.0          245.0
# 1  80.865220      111114      491.639100         1581.0           91.0
# 2  87.931539       63321      628.599659         2135.0          281.0
# 3  80.865220      111114      581.864896         2527.0          197.0
# 4  87.931539       63321      485.166675         1365.0          212.0
#
#    quartile25  quartile50  quartile75  quartile90  quartile95  quartile99  \
# 0       563.0       702.0       836.0       994.0     1120.70     1330.88
# 1       218.0       451.0       714.0       881.0      999.15     1251.00
# 2       499.0       597.0       719.0       860.0      958.70     1245.94
# 3       443.0       541.0       675.0       832.0      948.00     1294.00
# 4       408.0       466.0       543.0       628.0      690.00      826.00
#
#         stdev      skew  kurtosis  \
# 0  215.456444  0.592231  0.456316
# 1  290.527130  0.596004 -0.466833
# 2  182.527876  1.432031  3.856099
# 3  201.412917  1.674863  5.125393
# 4  109.588436  1.169953  2.501605
#
#                                     segmentation_mem
# 0                                                NaN
# 1  day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...
# 2                                                NaN
# 3  day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...
# 4                                                NaN

# %% [markdown]
# ## Organoid linking over multiplexing rounds

# %% [markdown]
# ## User input

# %%
#note all rounds must have the same plate names!
round_names = ['R0', 'R1', 'R2'] #ex. ['R0', 'R1', 'R2', 'R3'] always start with R0 and must be in sequential order

#must be in same order as round_names above
round_directories = ['/tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220528_GCPLEX_redo/20220507GCPLEX_R0/summary.csv',
                     '/tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220528_GCPLEX_redo/20220507GCPLEX_R1/summary.csv',
                    '/tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220528_GCPLEX_redo/20220507GCPLEX_R2/summary.csv']

# %% [markdown]
# ##### Load the data

# %%
exp_list = []
df_list = []

for i in range(len(round_names)):
    e = Experiment()
    e.load(round_directories[i])
    exp_list.append(e)
    
    path = os.path.join(e.get_experiment_dir(), 'org_df.csv')
    isExist = os.path.exists(path)
    
    if not isExist:
        print("ERROR! Run org_df aggregation on round ", round_names[i])
        continue

    # load organoid dataframe
    df = pd.read_csv(path)
    df_list.append(df)
    
# create dictionary with keys round names, values experiment objects or org_dfs
exps = dict(zip(round_names, exp_list))
dfs = dict(zip(round_names, df_list))

#dfs['R0']

# %%
link_names = []
link_list = []

for i in range(len(round_names)):
    if i > 0:
        path = os.path.join(exps['R0'].get_experiment_dir(), ('linking_org_R'+str(i)+'_df.csv'))
        isExist = os.path.exists(path)

        if not isExist:
            print("ERROR! Run organoid linking and linking_org_df aggregation of round ", round_names[i])
            continue

        # load linking dataframe
        df = pd.read_csv(path)
        df["id_R0"] = df["plate_id"] + "_" + df["well_id"] + "_" + df["R0_label"].astype(str)
        df["id_RX"] = df["plate_id"] + "_" + df["well_id"] + "_" + df["RX_label"].astype(str)
        link_names.append(round_names[i])
        link_list.append(df)

# create dictionary with keys round names, values linking dfs
links = dict(zip(link_names, link_list))

# %% [markdown]
# #### Link all rounds to round 0 numbering

# %%
org_df = pd.DataFrame()
#select organoids that are matched to R1
for i in range(len(round_names)-1):
    #i is 0
    right = dfs[round_names[i+1]] #load next round's df
    #right id is the organoid numbering relative to itself, i.e. RX
    right["id"] = right["plate_id"] + "_" + right["well_id"] + "_" + right["organoid_id"].str.split('_').str[1] #right["org_label"].astype(str)
    link = links[round_names[i+1]] #load linking
    link_dict = link.set_index("id_RX").T.to_dict('index')["id_R0"] #RX id is key, R0 is value
    
    #select right organoids that are matched to an R0 organoid
    #right_filt = right.copy(deep=True) #if do not want filtering, uncomment
    right_filt = right.loc[right["id"].isin(link_dict.keys()), :].copy(deep=True)
    
    right_filt["round_id"] = round_names[i+1] #add column with the round id
    right_filt["organoid_id_linked"] = right_filt["id"].map(link_dict) #Link!
    
    if i >0: #need to also select organoids that are in the org_df (i.e. linked R0-R1 organoids)
        linked_organoids = (org_df["plate_id"]  + "_" + org_df["well_id"] + "_" + org_df["org_label_linked"].astype(str)).unique()
        print(linked_organoids)
        right_filt = right_filt.loc[right_filt["organoid_id_linked"].isin(linked_organoids), :].copy(deep=True)
    
    right_filt["organoid_id_linked"] = "object_" + right_filt["organoid_id_linked"].str.split('_').str[2]
    right_filt["org_label_linked"] = right_filt["organoid_id_linked"].str.split('_').str[1].astype(float).astype('Int64')
    

    if i == 0: #if linking R0-R1, use the R0 df
        left = dfs[round_names[0]]
        left["id"] = left["plate_id"] + "_" + left["well_id"] + "_" + left["organoid_id"].str.split('_').str[1]
        left["round_id"] = round_names[0]
        left["organoid_id_linked"] = left["organoid_id"]
        left["org_label_linked"] = left["organoid_id_linked"].str.split('_').str[1].astype(int)
        #select R0 organoids that are matched to the next round 
        #to toggle, uncomment next line and comment subsequent
        left_filt = left.loc[left["id"].isin(link_dict.values()), :].copy(deep=True)
        #left_filt = left.copy(deep=True)
        
        
#WARNING! DID NOT TEST MORE THAN TWO ROUNDS YET, CHECK THAT THIS WORKS
    else: #if previous round linking already exists, use that df 
        left = org_df.copy(deep=True)
        #update "id" to match R0 numbering
        left["id"] = left["plate_id"] + "_" + left["well_id"] + "_" + left["organoid_id_linked"].str.split('_').str[1]
        #filter organoids that missing matches in previous rounds; 
        #so only have organoids that are linked across all rounds
        left_filt = left.loc[left["id"].isin(link_dict.values()), :].copy(deep=True)
        #if want organoids linked in R0-R1 but missing a link R0-R2, etc, uncomment next line
        #left_filt = left.copy(deep=True)
        

    org_df = pd.concat([left_filt, right_filt], ignore_index=True)
    
    #update sorting
    org_df = org_df.reset_index(drop=True)
    cols_to_move = ["plate_id","well_id", "org_label_linked", "round_id"]
    org_df = org_df[cols_to_move + [col for col in org_df.columns if col not in cols_to_move]]
    org_df = org_df.sort_values(by=cols_to_move)
    #multi-indexing
    #org_df = org_df.set_index(["plate_id","well_id", "org_label_linked", "round_id"]).sort_index()

#Save to R0 directory
org_df.to_csv(join(exps['R0'].get_experiment_dir(),("org_df_linked_" + '-'.join(round_names) + ".csv")), index=False) #saves csv
# Out:
# ['day1p5_B03_1' 'day1p5_B03_2' 'day1p5_B03_3' ... 'day4_B06_65'
#  'day4_B06_66' 'day4_B06_67']

# %%
org_df.head(40)
# Out:
#       plate_id well_id  org_label_linked round_id     hcs_experiment  \
# 0       day1p5     B03                 1       R0  20220507GCPLEX_R0
# 1       day1p5     B03                 1       R0  20220507GCPLEX_R0
# 2       day1p5     B03                 1       R0  20220507GCPLEX_R0
# 3       day1p5     B03                 1       R0  20220507GCPLEX_R0
# 4       day1p5     B03                 1       R1  20220507GCPLEX_R1
# 5       day1p5     B03                 1       R1  20220507GCPLEX_R1
# 6       day1p5     B03                 1       R1  20220507GCPLEX_R1
# 7       day1p5     B03                 1       R1  20220507GCPLEX_R1
# 12688   day1p5     B03                 1       R2  20220507GCPLEX_R2
# 12689   day1p5     B03                 1       R2  20220507GCPLEX_R2
# 12690   day1p5     B03                 1       R2  20220507GCPLEX_R2
# 12691   day1p5     B03                 1       R2  20220507GCPLEX_R2
# 8       day1p5     B03                 2       R0  20220507GCPLEX_R0
# 9       day1p5     B03                 2       R0  20220507GCPLEX_R0
# 10      day1p5     B03                 2       R0  20220507GCPLEX_R0
# 11      day1p5     B03                 2       R0  20220507GCPLEX_R0
# 12      day1p5     B03                 2       R1  20220507GCPLEX_R1
# 13      day1p5     B03                 2       R1  20220507GCPLEX_R1
# 14      day1p5     B03                 2       R1  20220507GCPLEX_R1
# 15      day1p5     B03                 2       R1  20220507GCPLEX_R1
# 12696   day1p5     B03                 2       R2  20220507GCPLEX_R2
# 12697   day1p5     B03                 2       R2  20220507GCPLEX_R2
# 12698   day1p5     B03                 2       R2  20220507GCPLEX_R2
# 12699   day1p5     B03                 2       R2  20220507GCPLEX_R2
# 16      day1p5     B03                 3       R0  20220507GCPLEX_R0
# 17      day1p5     B03                 3       R0  20220507GCPLEX_R0
# 18      day1p5     B03                 3       R0  20220507GCPLEX_R0
# 19      day1p5     B03                 3       R0  20220507GCPLEX_R0
# 20      day1p5     B03                 3       R1  20220507GCPLEX_R1
# 21      day1p5     B03                 3       R1  20220507GCPLEX_R1
# 22      day1p5     B03                 3       R1  20220507GCPLEX_R1
# 23      day1p5     B03                 3       R1  20220507GCPLEX_R1
# 12692   day1p5     B03                 3       R2  20220507GCPLEX_R2
# 12693   day1p5     B03                 3       R2  20220507GCPLEX_R2
# 12694   day1p5     B03                 3       R2  20220507GCPLEX_R2
# 12695   day1p5     B03                 3       R2  20220507GCPLEX_R2
# 24      day1p5     B03                 5       R0  20220507GCPLEX_R0
# 25      day1p5     B03                 5       R0  20220507GCPLEX_R0
# 26      day1p5     B03                 5       R0  20220507GCPLEX_R0
# 27      day1p5     B03                 5       R0  20220507GCPLEX_R0
#
#                                                 root_dir channel_id  \
# 0      /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C01
# 1      /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C02
# 2      /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C03
# 3      /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C04
# 4      /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C01
# 5      /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C02
# 6      /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C03
# 7      /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C04
# 12688  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C01
# 12689  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C02
# 12690  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C03
# 12691  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C04
# 8      /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C01
# 9      /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C02
# 10     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C03
# 11     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C04
# 12     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C01
# 13     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C02
# 14     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C03
# 15     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C04
# 12696  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C01
# 12697  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C02
# 12698  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C03
# 12699  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C04
# 16     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C01
# 17     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C02
# 18     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C03
# 19     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C04
# 20     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C01
# 21     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C02
# 22     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C03
# 23     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C04
# 12692  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C01
# 12693  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C02
# 12694  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C03
# 12695  /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C04
# 24     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C01
# 25     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C02
# 26     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C03
# 27     /tungstenfs/scratch/gliberal/Users/repinico/Yo...        C04
#
#       object_type organoid_id  org_label  \
# 0        organoid    object_1          1
# 1        organoid    object_1          1
# 2        organoid    object_1          1
# 3        organoid    object_1          1
# 4        organoid    object_2          2
# 5        organoid    object_2          2
# 6        organoid    object_2          2
# 7        organoid    object_2          2
# 12688    organoid    object_2          2
# 12689    organoid    object_2          2
# 12690    organoid    object_2          2
# 12691    organoid    object_2          2
# 8        organoid    object_2          2
# 9        organoid    object_2          2
# 10       organoid    object_2          2
# 11       organoid    object_2          2
# 12       organoid    object_4          4
# 13       organoid    object_4          4
# 14       organoid    object_4          4
# 15       organoid    object_4          4
# 12696    organoid    object_4          4
# 12697    organoid    object_4          4
# 12698    organoid    object_4          4
# 12699    organoid    object_4          4
# 16       organoid    object_3          3
# 17       organoid    object_3          3
# 18       organoid    object_3          3
# 19       organoid    object_3          3
# 20       organoid    object_3          3
# 21       organoid    object_3          3
# 22       organoid    object_3          3
# 23       organoid    object_3          3
# 12692    organoid    object_3          3
# 12693    organoid    object_3          3
# 12694    organoid    object_3          3
# 12695    organoid    object_3          3
# 24       organoid    object_5          5
# 25       organoid    object_5          5
# 26       organoid    object_5          5
# 27       organoid    object_5          5
#
#                                         segmentation_org  \
# 0      day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...
# 1      day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...
# 2      day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...
# 3      day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...
# 4      day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...
# 5      day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...
# 6      day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...
# 7      day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...
# 12688  day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...
# 12689  day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...
# 12690  day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...
# 12691  day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...
# 8      day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
# 9      day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
# 10     day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
# 11     day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
# 12     day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
# 13     day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
# 14     day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
# 15     day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
# 12696  day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
# 12697  day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
# 12698  day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
# 12699  day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
# 16     day1p5/obj_v0.3_ROI/B03/object_3/220509_092328...
# 17     day1p5/obj_v0.3_ROI/B03/object_3/220509_092328...
# 18     day1p5/obj_v0.3_ROI/B03/object_3/220509_092328...
# 19     day1p5/obj_v0.3_ROI/B03/object_3/220509_092328...
# 20     day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...
# 21     day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...
# 22     day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...
# 23     day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...
# 12692  day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...
# 12693  day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...
# 12694  day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...
# 12695  day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...
# 24     day1p5/obj_v0.3_ROI/B03/object_5/220509_092328...
# 25     day1p5/obj_v0.3_ROI/B03/object_5/220509_092328...
# 26     day1p5/obj_v0.3_ROI/B03/object_5/220509_092328...
# 27     day1p5/obj_v0.3_ROI/B03/object_5/220509_092328...
#
#                                            intensity_img  x_pos_pix  \
# 0      day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...  80.284971
# 1      day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...  80.284971
# 2      day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...  80.284971
# 3      day1p5/obj_v0.3_ROI/B03/object_1/220509_092328...  80.284971
# 4      day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...  81.449142
# 5      day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...  81.449142
# 6      day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...  81.449142
# 7      day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...  81.449142
# 12688  day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...  75.839043
# 12689  day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...  75.839043
# 12690  day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...  75.839043
# 12691  day1p5/obj_v0.3_ROI/B03/object_2/AssayPlate_Gr...  75.839043
# 8      day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...  81.173174
# 9      day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...  81.173174
# 10     day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...  81.173174
# 11     day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...  81.173174
# 12     day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...  80.903252
# 13     day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...  80.903252
# 14     day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...  80.903252
# 15     day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...  80.903252
# 12696  day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...  81.111193
# 12697  day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...  81.111193
# 12698  day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...  81.111193
# 12699  day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...  81.111193
# 16     day1p5/obj_v0.3_ROI/B03/object_3/220509_092328...  85.496873
# 17     day1p5/obj_v0.3_ROI/B03/object_3/220509_092328...  85.496873
# 18     day1p5/obj_v0.3_ROI/B03/object_3/220509_092328...  85.496873
# 19     day1p5/obj_v0.3_ROI/B03/object_3/220509_092328...  85.496873
# 20     day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...  80.493926
# 21     day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...  80.493926
# 22     day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...  80.493926
# 23     day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...  80.493926
# 12692  day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...  78.622660
# 12693  day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...  78.622660
# 12694  day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...  78.622660
# 12695  day1p5/obj_v0.3_ROI/B03/object_3/AssayPlate_Gr...  78.622660
# 24     day1p5/obj_v0.3_ROI/B03/object_5/220509_092328...  76.705031
# 25     day1p5/obj_v0.3_ROI/B03/object_5/220509_092328...  76.705031
# 26     day1p5/obj_v0.3_ROI/B03/object_5/220509_092328...  76.705031
# 27     day1p5/obj_v0.3_ROI/B03/object_5/220509_092328...  76.705031
#
#        y_pos_pix  x_pos_weighted_pix  y_pos_weighted_pix  x_massDisp_pix  \
# 0      72.781879           74.881082           76.241840       -5.403889
# 1      72.781879           77.985616           70.632944       -2.299355
# 2      72.781879           77.740654           70.364672       -2.544317
# 3      72.781879           76.558488           64.756100       -3.726483
# 4      80.320939           78.237271           89.624118       -3.211871
# 5      80.320939           80.654571           82.093364       -0.794571
# 6      80.320939           80.213020           80.806564       -1.236122
# 7      80.320939           78.871375           82.725880       -2.577767
# 12688  83.842421           70.197152           88.944785       -5.641891
# 12689  83.842421           74.044387           83.970509       -1.794656
# 12690  83.842421           72.114843           83.006749       -3.724200
# 12691  83.842421           74.518553           84.225321       -1.320489
# 8      82.397178           79.445791           81.817100       -1.727383
# 9      82.397178           82.701005           83.136665        1.527831
# 10     82.397178           77.997939           82.961412       -3.175235
# 11     82.397178           81.061242           79.138620       -0.111933
# 12     83.397672           80.419810           83.427773       -0.483442
# 13     83.397672           81.244501           83.619501        0.341249
# 14     83.397672           78.611146           84.108768       -2.292106
# 15     83.397672           81.071825           83.705820        0.168573
# 12696  83.730568           82.196901           82.646677        1.085708
# 12697  83.730568           82.839584           83.451101        1.728391
# 12698  83.730568           81.207602           83.260377        0.096409
# 12699  83.730568           81.476987           83.334672        0.365794
# 16     76.949973           87.942202           78.202962        2.445329
# 17     76.949973           88.670997           77.487065        3.174124
# 18     76.949973           87.488145           78.831722        1.991272
# 19     76.949973           90.942140           80.777655        5.445266
# 20     82.909438           81.800672           82.284000        1.306746
# 21     82.909438           81.244643           82.774994        0.750717
# 22     82.909438           80.527688           82.950216        0.033762
# 23     82.909438           80.113782           84.671185       -0.380144
# 12692  82.413742           79.326720           83.785869        0.704061
# 12693  82.413742           79.223506           83.221415        0.600846
# 12694  82.413742           78.569546           84.245784       -0.053113
# 12695  82.413742           78.830909           83.366800        0.208250
# 24     72.589727           73.639256           73.431347       -3.065775
# 25     72.589727           79.724418           76.815371        3.019386
# 26     72.589727           80.405644           73.998610        3.700613
# 27     72.589727           79.323771           78.747598        2.618739
#
#        y_massDisp_pix  mean_intensityMIP  max_intensity  min_intensity  \
# 0            3.459961         539.219888         1898.0          116.0
# 1           -2.148935         792.685481         2897.0          244.0
# 2           -2.417207         641.267007         1961.0          199.0
# 3           -8.025779        3278.987631        16773.0          187.0
# 4            9.303180        1447.239582         5370.0          136.0
# 5            1.772426         388.388146          831.0          152.0
# 6            0.485625         199.044086          360.0          118.0
# 7            2.404941         247.430420          401.0          118.0
# 12688        5.102364         469.378132         1489.0          112.0
# 12689        0.128087         262.971750          421.0          141.0
# 12690       -0.835673         717.686344         1402.0          173.0
# 12691        0.382899         157.679962          241.0          110.0
# 8           -0.580078         581.071194         1621.0          121.0
# 9            0.739487        4119.516476        29143.0          256.0
# 10           0.564234        2447.569149        13893.0          184.0
# 11          -3.258558        3997.643229        16596.0          219.0
# 12           0.030101        1499.550863         4426.0          144.0
# 13           0.221829         555.865034         1777.0          146.0
# 14           0.711097         309.619591         1196.0          110.0
# 15           0.308148         296.495223          535.0          116.0
# 12696       -1.083890         499.123384         1359.0          117.0
# 12697       -0.279467         394.578792         1473.0          139.0
# 12698       -0.470191        1079.932662         3775.0          145.0
# 12699       -0.395896         167.558992          610.0          110.0
# 16           1.252989         526.470341         1724.0          117.0
# 17           0.537092         817.421833         6550.0          205.0
# 18           1.881749        1110.861265         5123.0          178.0
# 19           3.827681        3799.010899        13844.0          222.0
# 20          -0.625438        1400.349248         5283.0          139.0
# 21          -0.134444         386.686433          615.0          144.0
# 22           0.040777         227.679636          591.0          114.0
# 23           1.761746         261.574293          536.0          108.0
# 12692        1.372127         456.805539         1542.0          112.0
# 12693        0.807673         268.417922          435.0          134.0
# 12694        1.832042         773.586606         6260.0          139.0
# 12695        0.953058         159.131063          268.0          109.0
# 24           0.841620         595.847799         1915.0          116.0
# 25           4.225644        3696.658491        24935.0          225.0
# 26           1.408882        9803.225786        43990.0          314.0
# 27           6.157870        3685.288994        20001.0          183.0
#
#        abs_min  area_pix  eccentricity  majorAxisLength  minorAxisLength  \
# 0        108.0   10187.0      0.516293       123.174352       105.487968
# 1        155.0   10187.0      0.516293       123.174352       105.487968
# 2        143.0   10187.0      0.516293       123.174352       105.487968
# 3        119.0   10187.0      0.516293       123.174352       105.487968
# 4        112.0   11591.0      0.427287       127.886036       115.623824
# 5        134.0   11591.0      0.427287       127.886036       115.623824
# 6        108.0   11591.0      0.427287       127.886036       115.623824
# 7        111.0   11591.0      0.427287       127.886036       115.623824
# 12688    106.0   10655.0      0.439405       123.151773       110.625867
# 12689    125.0   10655.0      0.439405       123.151773       110.625867
# 12690    116.0   10655.0      0.439405       123.151773       110.625867
# 12691    106.0   10655.0      0.439405       123.151773       110.625867
# 8        108.0   12473.0      0.263385       128.393575       123.860087
# 9        158.0   12473.0      0.263385       128.393575       123.860087
# 10       127.0   12473.0      0.263385       128.393575       123.860087
# 11       122.0   12473.0      0.263385       128.393575       123.860087
# 12       109.0   12455.0      0.304876       129.070834       122.926035
# 13       124.0   12455.0      0.304876       129.070834       122.926035
# 14       106.0   12455.0      0.304876       129.070834       122.926035
# 15       107.0   12455.0      0.304876       129.070834       122.926035
# 12696    105.0   12222.0      0.304697       127.855663       121.776030
# 12697    124.0   12222.0      0.304697       127.855663       121.776030
# 12698    116.0   12222.0      0.304697       127.855663       121.776030
# 12699    105.0   12222.0      0.304697       127.855663       121.776030
# 16       108.0   11194.0      0.420063       125.486547       113.878388
# 17       152.0   11194.0      0.420063       125.486547       113.878388
# 18       123.0   11194.0      0.420063       125.486547       113.878388
# 19       123.0   11194.0      0.420063       125.486547       113.878388
# 20       113.0   11771.0      0.342601       126.366810       118.719221
# 21       129.0   11771.0      0.342601       126.366810       118.719221
# 22       105.0   11771.0      0.342601       126.366810       118.719221
# 23       107.0   11771.0      0.342601       126.366810       118.719221
# 12692    104.0   11483.0      0.396686       126.235343       115.878259
# 12693    124.0   11483.0      0.396686       126.235343       115.878259
# 12694    115.0   11483.0      0.396686       126.235343       115.878259
# 12695    104.0   11483.0      0.396686       126.235343       115.878259
# 24       108.0    9540.0      0.511237       118.951265       102.231442
# 25       158.0    9540.0      0.511237       118.951265       102.231442
# 26       172.0    9540.0      0.511237       118.951265       102.231442
# 27       119.0    9540.0      0.511237       118.951265       102.231442
#
#        axisRatio  eulerNumber  objectBoxRatio   perimeter  circularity  \
# 0       0.856412            1        0.427307  379.019336     0.891114
# 1       0.856412            1        0.427307  379.019336     0.891114
# 2       0.856412            1        0.427307  379.019336     0.891114
# 3       0.856412            1        0.427307  379.019336     0.891114
# 4       0.904116            1        0.433698  405.060967     0.887749
# 5       0.904116            1        0.433698  405.060967     0.887749
# 6       0.904116            1        0.433698  405.060967     0.887749
# 7       0.904116            1        0.433698  405.060967     0.887749
# 12688   0.898289            1        0.416618  381.688384     0.919063
# 12689   0.898289            1        0.416618  381.688384     0.919063
# 12690   0.898289            1        0.416618  381.688384     0.919063
# 12691   0.898289            1        0.416618  381.688384     0.919063
# 8       0.964691            1        0.449964  418.818326     0.893572
# 9       0.964691            1        0.449964  418.818326     0.893572
# 10      0.964691            1        0.449964  418.818326     0.893572
# 11      0.964691            1        0.449964  418.818326     0.893572
# 12      0.952392            1        0.457635  414.575685     0.910638
# 13      0.952392            1        0.457635  414.575685     0.910638
# 14      0.952392            1        0.457635  414.575685     0.910638
# 15      0.952392            1        0.457635  414.575685     0.910638
# 12696   0.952449            1        0.451863  411.989899     0.904855
# 12697   0.952449            1        0.451863  411.989899     0.904855
# 12698   0.952449            1        0.451863  411.989899     0.904855
# 12699   0.952449            1        0.451863  411.989899     0.904855
# 16      0.907495            1        0.429877  395.889394     0.897527
# 17      0.907495            1        0.429877  395.889394     0.897527
# 18      0.907495            1        0.429877  395.889394     0.897527
# 19      0.907495            1        0.429877  395.889394     0.897527
# 20      0.939481            1        0.443185  404.232539     0.905234
# 21      0.939481            1        0.443185  404.232539     0.905234
# 22      0.939481            1        0.443185  404.232539     0.905234
# 23      0.939481            1        0.443185  404.232539     0.905234
# 12692   0.917954            1        0.443428  395.646753     0.921828
# 12693   0.917954            1        0.443428  395.646753     0.921828
# 12694   0.917954            1        0.443428  395.646753     0.921828
# 12695   0.917954            1        0.443428  395.646753     0.921828
# 24      0.859440            1        0.421751  365.362482     0.898070
# 25      0.859440            1        0.421751  365.362482     0.898070
# 26      0.859440            1        0.421751  365.362482     0.898070
# 27      0.859440            1        0.421751  365.362482     0.898070
#
#        quartile25  quartile50  quartile75  quartile90  quartile95  quartile99  \
# 0          147.00       521.0      856.00      1081.0     1227.70     1486.42
# 1          598.00       770.0      947.00      1148.4     1312.70     1744.98
# 2          528.00       642.0      754.00       865.0      944.00     1190.00
# 3          940.00      1982.0     4690.50      8626.8    10160.50    12409.56
# 4          217.00       947.0     2579.00      3256.0     3649.50     4428.40
# 5          352.00       412.0      458.00       496.0      517.00      556.00
# 6          177.00       202.0      222.00       241.0      251.00      274.00
# 7          203.00       266.0      293.00       312.0      323.00      345.00
# 12688      143.00       441.0      742.50       934.0     1054.00     1250.46
# 12689      247.00       271.0      291.00       308.0      319.00      342.46
# 12690      635.00       756.0      849.00       926.0      977.00     1087.00
# 12691      146.00       158.0      170.00       180.6      188.00      202.00
# 8          197.00       645.0      818.00       987.0     1082.00     1266.28
# 9          832.00      1781.0     6629.00     10259.8    12711.40    17673.56
# 10         671.00      1094.0     4004.00      5825.8     6918.00     9339.48
# 11        1579.00      3518.0     5829.00      7997.4     9339.00    12193.44
# 12         316.00      1733.0     2218.00      2720.6     2996.30     3523.92
# 13         402.00       491.0      710.00       912.0     1023.00     1247.00
# 14         204.00       247.0      397.00       529.0      616.00      809.92
# 15         255.00       311.0      352.00       388.0      412.00      458.46
# 12696      166.00       551.0      715.00       856.0      937.00     1092.79
# 12697      273.00       328.0      500.00       670.0      756.95      929.00
# 12698      779.00       963.0     1366.00      1776.0     2062.95     2733.58
# 12699      154.00       167.0      181.00       194.0      203.00      228.00
# 16         178.00       532.0      769.00       961.0     1083.35     1328.00
# 17         633.00       801.0      964.00      1150.7     1297.00     1773.07
# 18         809.25      1069.0     1381.00      1714.7     1982.35     2606.42
# 19        1643.25      3594.5     5463.00      7244.7     8342.35    10335.00
# 20         259.00      1464.0     2211.00      2797.0     3155.00     3870.80
# 21         364.00       412.0      447.00       477.0      496.00      536.00
# 22         200.00       230.0      260.00       289.0      308.00      357.00
# 23         224.00       271.0      302.00       342.0      385.00      444.00
# 12692      152.00       452.0      677.00       836.0      948.00     1179.18
# 12693      252.00       280.0      301.00       319.0      331.00      353.00
# 12694      694.00       815.0      913.00       998.0     1051.00     1175.18
# 12695      149.00       160.0      171.00       182.0      188.00      203.00
# 24         149.75       676.0      923.00      1113.1     1218.00     1435.00
# 25         970.00      2864.0     5165.25      8190.2    10073.00    14914.47
# 26        1205.75      7775.0    15870.25     22724.9    27153.25    35277.54
# 27        1242.75      2884.5     5363.25      8290.0    10047.15    12686.10
#
#              stdev      skew   kurtosis  nuc_without_mem  nuc_total  \
# 0       399.261889  0.512794  -0.894206              0.0        4.0
# 1       297.225611  1.037814   2.771971              0.0        4.0
# 2       194.596256  0.439194   1.577212              0.0        4.0
# 3      3153.667412  1.294163   0.783935              0.0        4.0
# 4      1305.312483  0.500949  -1.112155              NaN        NaN
# 5       100.687665 -0.744183  -0.282666              NaN        NaN
# 6        34.425233 -0.137015  -0.341681              NaN        NaN
# 7        60.714010 -0.608446  -0.826927              NaN        NaN
# 12688   334.925587  0.499184  -1.001783              NaN        NaN
# 12689    42.878175 -0.839203   0.386565              NaN        NaN
# 12690   202.037328 -0.941641   0.677107              NaN        NaN
# 12691    18.367360  0.076764  -0.117047              NaN        NaN
# 8       326.109188  0.004882  -1.049035              0.0        8.0
# 9      4304.492493  1.401060   1.839414              0.0        8.0
# 10     2316.478899  1.196969   0.882953              0.0        8.0
# 11     2850.210582  0.844446   0.424171              0.0        8.0
# 12      986.740780 -0.013295  -1.141546              NaN        NaN
# 13      249.389283  0.821624   0.639647              NaN        NaN
# 14      155.144343  1.415257   2.278973              NaN        NaN
# 15       82.014091 -0.502727  -0.341106              NaN        NaN
# 12696   282.437297  0.063637  -1.139149              NaN        NaN
# 12697   184.177416  1.111351   0.999834              NaN        NaN
# 12698   529.188560  0.929489   1.581060              NaN        NaN
# 12699    28.098473  4.102408  47.418738              NaN        NaN
# 16      327.817546  0.415446  -0.694253              0.0        8.0
# 17      333.430590  3.117099  29.914276              0.0        8.0
# 18      505.107368  0.928085   2.881375              0.0        8.0
# 19     2512.824809  0.563178  -0.218669              0.0        8.0
# 20     1056.137062  0.369788  -0.848276              NaN        NaN
# 21       94.352561 -1.104535   0.406181              NaN        NaN
# 22       51.862434  0.142409   0.913238              NaN        NaN
# 23       73.128441 -0.066350   0.067710              NaN        NaN
# 12692   287.630167  0.481623  -0.665086              NaN        NaN
# 12693    49.866524 -0.919928   0.189753              NaN        NaN
# 12694   244.099559  1.750057  44.219302              NaN        NaN
# 12695    18.714463 -0.048251   0.241954              NaN        NaN
# 24      403.403088  0.200366  -1.244339              0.0        6.0
# 25     3289.044034  1.501725   2.803512              0.0        6.0
# 26     9004.423516  0.904054   0.153857              0.0        6.0
# 27     3077.741162  1.111193   0.906414              0.0        6.0
#
#        mem_without_nuc  mem_total  nuc_count  \
# 0                  2.0        6.0          4
# 1                  2.0        6.0          4
# 2                  2.0        6.0          4
# 3                  2.0        6.0          4
# 4                  NaN        NaN          4
# 5                  NaN        NaN          4
# 6                  NaN        NaN          4
# 7                  NaN        NaN          4
# 12688              NaN        NaN          4
# 12689              NaN        NaN          4
# 12690              NaN        NaN          4
# 12691              NaN        NaN          4
# 8                  1.0        9.0          8
# 9                  1.0        9.0          8
# 10                 1.0        9.0          8
# 11                 1.0        9.0          8
# 12                 NaN        NaN          8
# 13                 NaN        NaN          8
# 14                 NaN        NaN          8
# 15                 NaN        NaN          8
# 12696              NaN        NaN          8
# 12697              NaN        NaN          8
# 12698              NaN        NaN          8
# 12699              NaN        NaN          8
# 16                 1.0        9.0          8
# 17                 1.0        9.0          8
# 18                 1.0        9.0          8
# 19                 1.0        9.0          8
# 20                 NaN        NaN          8
# 21                 NaN        NaN          8
# 22                 NaN        NaN          8
# 23                 NaN        NaN          8
# 12692              NaN        NaN          8
# 12693              NaN        NaN          8
# 12694              NaN        NaN          8
# 12695              NaN        NaN          8
# 24                 0.0        6.0          6
# 25                 0.0        6.0          6
# 26                 0.0        6.0          6
# 27                 0.0        6.0          6
#
#                                         segmentation_ovr  flag_tile_border  \
# 0      day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 1      day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 2      day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 3      day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 4      day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 5      day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 6      day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 7      day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12688  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12689  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12690  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12691  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 8      day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 9      day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 10     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 11     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 12     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 13     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 14     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 15     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12696  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12697  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12698  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12699  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 16     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 17     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 18     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 19     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 20     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 21     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 22     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 23     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12692  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12693  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12694  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 12695  day1p5/TIF_OVR_MIP_SEG/obj_v0.3/AssayPlate_Gre...             False
# 24     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 25     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 26     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
# 27     day1p5/TIF_OVR_MIP_SEG/obj_v0.3/220509_092328_...             False
#
#        x_pos_pix_global  y_pos_pix_global  area_pix_global            id  \
# 0          11862.284971        459.781879          10187.0  day1p5_B03_1
# 1          11862.284971        459.781879          10187.0  day1p5_B03_1
# 2          11862.284971        459.781879          10187.0  day1p5_B03_1
# 3          11862.284971        459.781879          10187.0  day1p5_B03_1
# 4          11779.449142        557.320939          11591.0  day1p5_B03_1
# 5          11779.449142        557.320939          11591.0  day1p5_B03_1
# 6          11779.449142        557.320939          11591.0  day1p5_B03_1
# 7          11779.449142        557.320939          11591.0  day1p5_B03_1
# 12688      11796.839043        609.842421          10655.0  day1p5_B03_2
# 12689      11796.839043        609.842421          10655.0  day1p5_B03_2
# 12690      11796.839043        609.842421          10655.0  day1p5_B03_2
# 12691      11796.839043        609.842421          10655.0  day1p5_B03_2
# 8           8197.173174       1187.397178          12473.0  day1p5_B03_2
# 9           8197.173174       1187.397178          12473.0  day1p5_B03_2
# 10          8197.173174       1187.397178          12473.0  day1p5_B03_2
# 11          8197.173174       1187.397178          12473.0  day1p5_B03_2
# 12          8117.903252       1290.397672          12455.0  day1p5_B03_2
# 13          8117.903252       1290.397672          12455.0  day1p5_B03_2
# 14          8117.903252       1290.397672          12455.0  day1p5_B03_2
# 15          8117.903252       1290.397672          12455.0  day1p5_B03_2
# 12696       8124.111193       1338.730568          12222.0  day1p5_B03_4
# 12697       8124.111193       1338.730568          12222.0  day1p5_B03_4
# 12698       8124.111193       1338.730568          12222.0  day1p5_B03_4
# 12699       8124.111193       1338.730568          12222.0  day1p5_B03_4
# 16          5894.496873       1128.949973          11194.0  day1p5_B03_3
# 17          5894.496873       1128.949973          11194.0  day1p5_B03_3
# 18          5894.496873       1128.949973          11194.0  day1p5_B03_3
# 19          5894.496873       1128.949973          11194.0  day1p5_B03_3
# 20          5817.493926       1236.909438          11771.0  day1p5_B03_3
# 21          5817.493926       1236.909438          11771.0  day1p5_B03_3
# 22          5817.493926       1236.909438          11771.0  day1p5_B03_3
# 23          5817.493926       1236.909438          11771.0  day1p5_B03_3
# 12692       5827.622660       1278.413742          11483.0  day1p5_B03_3
# 12693       5827.622660       1278.413742          11483.0  day1p5_B03_3
# 12694       5827.622660       1278.413742          11483.0  day1p5_B03_3
# 12695       5827.622660       1278.413742          11483.0  day1p5_B03_3
# 24         10264.705031       1697.589727           9540.0  day1p5_B03_5
# 25         10264.705031       1697.589727           9540.0  day1p5_B03_5
# 26         10264.705031       1697.589727           9540.0  day1p5_B03_5
# 27         10264.705031       1697.589727           9540.0  day1p5_B03_5
#
#       organoid_id_linked
# 0               object_1
# 1               object_1
# 2               object_1
# 3               object_1
# 4               object_1
# 5               object_1
# 6               object_1
# 7               object_1
# 12688           object_1
# 12689           object_1
# 12690           object_1
# 12691           object_1
# 8               object_2
# 9               object_2
# 10              object_2
# 11              object_2
# 12              object_2
# 13              object_2
# 14              object_2
# 15              object_2
# 12696           object_2
# 12697           object_2
# 12698           object_2
# 12699           object_2
# 16              object_3
# 17              object_3
# 18              object_3
# 19              object_3
# 20              object_3
# 21              object_3
# 22              object_3
# 23              object_3
# 12692           object_3
# 12693           object_3
# 12694           object_3
# 12695           object_3
# 24              object_5
# 25              object_5
# 26              object_5
# 27              object_5

# %%
org_df.shape
# Out:
# (19028, 52)

# %% [markdown]
# ## Nuclear linking over multiplexing rounds with PlatyMatch

# %%
#note all rounds must have the same plate names!
round_names = ['R0', 'R1', 'R2'] #ex. ['R0', 'R1', 'R2', 'R3'] always start with R0 and must be in sequential order

# #must be in same order as round_names above
# round_directories = ['/tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220525_GCPLEX/20220507GCPLEX_R0/summary.csv',
#                      '/tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220525_GCPLEX/20220507GCPLEX_R1/summary.csv',
#                     '/tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220525_GCPLEX/20220507GCPLEX_R2/summary.csv']

#must be in same order as round_names above
round_directories = ['/tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220528_GCPLEX_redo/20220507GCPLEX_R0/summary.csv',
                     '/tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220528_GCPLEX_redo/20220507GCPLEX_R1/summary.csv',
                    '/tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220528_GCPLEX_redo/20220507GCPLEX_R2/summary.csv']

# %% [markdown]
# ##### Load the data

# %%
exp_list = []
df_list = []

for i in range(len(round_names)):
    e = Experiment()
    e.load(round_directories[i])
    exp_list.append(e)
    
    path = os.path.join(e.get_experiment_dir(), 'nuc_df.csv')
    isExist = os.path.exists(path)
    
    if not isExist:
        print("ERROR! Run nuc_df aggregation on round ", round_names[i])
        continue

    # load nuc dataframe
    df = pd.read_csv(path)
    df_list.append(df)
    
# create dictionary with keys round names, values experiment objects or nuc_dfs
exps = dict(zip(round_names, exp_list))
dfs = dict(zip(round_names, df_list))

#dfs['R0']

# %%
link_names = []
link_list = []

for i in range(len(round_names)):
    #skip R0
    if i > 0:
        path = os.path.join(exps['R0'].get_experiment_dir(), ('linking_nuc_R'+str(i)+'_df.csv'))
        print(path)
        isExist = os.path.exists(path)

        if not isExist:
            print("ERROR! Run organoid linking and linking_nuc_df aggregation of round ", round_names[i])
            continue

        # load linking dataframe
        df = pd.read_csv(path)
        df["id_R0"] = df["plate_id"] + "_" + df["well_id"] + "_" + df["R0_organoid_id"].str.split('_').str[1] + "_" + df["R0_nuc_id"].astype(int).astype(str)
        df["id_RX"] = df["plate_id"] + "_" + df["well_id"] + "_" + df["RX_organoid_id"].str.split('_').str[1] + "_" + df["RX_nuc_id"].astype(int).astype(str)
        link_names.append(round_names[i])
        link_list.append(df)

# create dictionary with keys round names, values linking dfs
links = dict(zip(link_names, link_list))
# Out:
# /tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220528_GCPLEX_redo/20220507GCPLEX_R0/linking_nuc_R1_df.csv
# /tungstenfs/scratch/gliberal/Users/repinico/Microscopy/Analysis/20220528_GCPLEX_redo/20220507GCPLEX_R0/linking_nuc_R2_df.csv

# %%
link_list
# Out:
# [       R0_nuc_id  RX_nuc_id R0_organoid_id RX_organoid_id plate_id well_id  \
#  0            1.0        1.0      object_12      object_11   day2p5     B04
#  1            2.0        2.0      object_12      object_11   day2p5     B04
#  2            3.0        5.0      object_12      object_11   day2p5     B04
#  3            4.0        4.0      object_12      object_11   day2p5     B04
#  4            5.0        3.0      object_12      object_11   day2p5     B04
#  ...          ...        ...            ...            ...      ...     ...
#  88704      274.0      301.0       object_4       object_5     day4     B03
#  88705      275.0      305.0       object_4       object_5     day4     B03
#  88706      276.0      303.0       object_4       object_5     day4     B03
#  88707      277.0      306.0       object_4       object_5     day4     B03
#  88708      278.0      307.0       object_4       object_5     day4     B03
#
#                   id_R0            id_RX
#  0      day2p5_B04_12_1  day2p5_B04_11_1
#  1      day2p5_B04_12_2  day2p5_B04_11_2
#  2      day2p5_B04_12_3  day2p5_B04_11_5
#  3      day2p5_B04_12_4  day2p5_B04_11_4
#  4      day2p5_B04_12_5  day2p5_B04_11_3
#  ...                ...              ...
#  88704   day4_B03_4_274   day4_B03_5_301
#  88705   day4_B03_4_275   day4_B03_5_305
#  88706   day4_B03_4_276   day4_B03_5_303
#  88707   day4_B03_4_277   day4_B03_5_306
#  88708   day4_B03_4_278   day4_B03_5_307
#
#  [88709 rows x 8 columns],
#         R0_nuc_id  RX_nuc_id R0_organoid_id RX_organoid_id plate_id well_id  \
#  0            1.0        1.0      object_12      object_12   day2p5     B04
#  1            2.0        2.0      object_12      object_12   day2p5     B04
#  2            3.0        5.0      object_12      object_12   day2p5     B04
#  3            4.0        4.0      object_12      object_12   day2p5     B04
#  4            5.0        3.0      object_12      object_12   day2p5     B04
#  ...          ...        ...            ...            ...      ...     ...
#  86960      262.0      295.0       object_4       object_5     day4     B03
#  86961      263.0      299.0       object_4       object_5     day4     B03
#  86962      264.0      302.0       object_4       object_5     day4     B03
#  86963      265.0      300.0       object_4       object_5     day4     B03
#  86964      266.0      307.0       object_4       object_5     day4     B03
#
#                   id_R0            id_RX
#  0      day2p5_B04_12_1  day2p5_B04_12_1
#  1      day2p5_B04_12_2  day2p5_B04_12_2
#  2      day2p5_B04_12_3  day2p5_B04_12_5
#  3      day2p5_B04_12_4  day2p5_B04_12_4
#  4      day2p5_B04_12_5  day2p5_B04_12_3
#  ...                ...              ...
#  86960   day4_B03_4_262   day4_B03_5_295
#  86961   day4_B03_4_263   day4_B03_5_299
#  86962   day4_B03_4_264   day4_B03_5_302
#  86963   day4_B03_4_265   day4_B03_5_300
#  86964   day4_B03_4_266   day4_B03_5_307
#
#  [86965 rows x 8 columns]]

# %%
pd.set_option("display.max_rows", 300)
pd.set_option("display.max_columns", 300)

# %% [markdown]
# #### Link all rounds to round 0 numbering

# %%
nuc_df = pd.DataFrame()
#nuc_id_linked and organoid_id_linked is always the R0 numbering

for i in range(len(round_names)-1):
    right = dfs[round_names[i+1]] #load next round's df
    right["id"] = right["plate_id"] + "_" + right["well_id"] + "_" + right["organoid_id"].str.split('_').str[1] + "_" + right["nuc_id"].astype(int).astype(str)
    link = links[round_names[i+1]] #load linking
    
    #discard all labels in RX that are not mapped to a single label in R0
    link["duplicated"] = link["id_RX"].duplicated() 
    #if want to keep first duplicate of label, remove keep=False
    link_filtered = link[link['duplicated'] == False]
    print("removed", len(link) - len(link_filtered), "duplicated RX nuclei")

    link_dict = link_filtered.set_index("id_RX").T.to_dict('index')["id_R0"] #RX id is key, R0 is value
    
    #select right organoids that are matched to R0 round
    #right_filt = right.copy(deep=True)
    right_filt = right.loc[right["id"].isin(link_dict.keys()), :].copy(deep=True)
    right_filt["round_id"] = round_names[i+1] #add column with the round id
    right_filt["nuc_id_linked"] = right_filt["id"].map(link_dict) #link!
    # add R0 organoid id and label that the RX nuc is linked to
    right_filt["organoid_id_linked"] = "object_" + right_filt["nuc_id_linked"].str.split('_').str[2]
    right_filt["org_label_linked"] = right_filt["organoid_id_linked"].str.split('_').str[1].astype(float).astype('Int64')
    
    if i >0: #need to also select nuclei that are already in the nuc_df (i.e. linked R0-R1 nuclei)
        linked_nuclei = (nuc_df["plate_id"]  + "_" + nuc_df["well_id"] + "_" + nuc_df["org_label_linked"].astype(int).astype(str) + "_" + nuc_df["nuc_id_linked"].astype(int).astype(str)).unique()
        right_filt = right_filt.loc[right_filt["nuc_id_linked"].isin(linked_nuclei), :].copy(deep=True)
    
    # add R0 nuclear label that the RX nuc is linked to
    right_filt["nuc_id_linked"] = right_filt["nuc_id_linked"].str.split('_').str[3].astype(float).astype('Int64')
    
    if i == 0: #if linking R0-R1, use the R0 df
        left = dfs[round_names[0]]
        left["id"] = left["plate_id"] + "_" + left["well_id"] + "_" + left["organoid_id"].str.split('_').str[1] + "_" + left["nuc_id"].astype(int).astype(str)
        left["round_id"] = round_names[0]
        left["nuc_id_linked"] = left["nuc_id"].astype(int)
        left["organoid_id_linked"] = left["organoid_id"]
        left["org_label_linked"] = left["organoid_id_linked"].str.split('_').str[1].astype(int)
        #select R0 nuclei that are matched to the next round (different from organoid linking default!) 
        #if want to change that all R0 nuc kept, comment next line and uncomment subsequent
        left_filt = left.loc[left["id"].isin(link_dict.values()), :].copy(deep=True)
        #left_filt = left.copy(deep=True)
               
    #WARNING! DID NOT TEST MORE THAN TWO ROUNDS YET, CHECK THAT THIS WORKS
    else: #if previous round linking already exists, use that df 
        left = nuc_df.copy(deep=True)
        #update "id" to match R0 numbering
        left["id"] = left["plate_id"] + "_" + left["well_id"] + "_" + left["organoid_id_linked"].str.split('_').str[1] + "_" + left["nuc_id_linked"].astype(int).astype(str)
        #select R0 nuclei that are matched to the RX round
        #if want to change that all R0 nuc kept, comment next line and uncomment subsequent
        #this means that output nuclei are successfully matched across all rounds
        left_filt = left.loc[left["id"].isin(link_dict.values()), :].copy(deep=True)
        #left_filt = left.copy(deep=True)


    nuc_df = pd.concat([left_filt, right_filt], ignore_index=True)
    
    #update sorting
    nuc_df = nuc_df.reset_index(drop=True)
    cols_to_move = ["plate_id","well_id", "org_label_linked", "nuc_id_linked", "round_id"]
    nuc_df = nuc_df[cols_to_move + [col for col in nuc_df.columns if col not in cols_to_move]]
    nuc_df = nuc_df.sort_values(by=cols_to_move)
    
#Save to R0 directory
nuc_df.to_csv(join(exps['R0'].get_experiment_dir(),("nuc_df_linked_" + '-'.join(round_names) + ".csv")), index=False) #saves csv

#multi-indexing
#nuc_df = nuc_df.set_index(["plate_id","well_id", "org_label_linked", "nuc_id_linked", "round_id"]).sort_index()
# Out:
# removed 0 duplicated RX nuclei
# removed 0 duplicated RX nuclei

# %%
#link_dict

# %%
nuc_df = nuc_df.set_index(["plate_id","well_id", "org_label_linked", "nuc_id_linked", "round_id"]).sort_index()
nuc_df.head(n=40)
#print(left.shape[0], left_filt.shape[0])
# Out:
#                                                              hcs_experiment  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R1        20220507GCPLEX_R1
#                                                 R1        20220507GCPLEX_R1
#                                                 R1        20220507GCPLEX_R1
#                                                 R1        20220507GCPLEX_R1
#                                                 R2        20220507GCPLEX_R2
#                                                 R2        20220507GCPLEX_R2
#                                                 R2        20220507GCPLEX_R2
#                                                 R2        20220507GCPLEX_R2
#                                   2             R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R1        20220507GCPLEX_R1
#                                                 R1        20220507GCPLEX_R1
#                                                 R1        20220507GCPLEX_R1
#                                                 R1        20220507GCPLEX_R1
#                                                 R2        20220507GCPLEX_R2
#                                                 R2        20220507GCPLEX_R2
#                                                 R2        20220507GCPLEX_R2
#                                                 R2        20220507GCPLEX_R2
#                                   3             R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R1        20220507GCPLEX_R1
#                                                 R1        20220507GCPLEX_R1
#                                                 R1        20220507GCPLEX_R1
#                                                 R1        20220507GCPLEX_R1
#                                                 R2        20220507GCPLEX_R2
#                                                 R2        20220507GCPLEX_R2
#                                                 R2        20220507GCPLEX_R2
#                                                 R2        20220507GCPLEX_R2
#                                   4             R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#                                                 R0        20220507GCPLEX_R0
#
#                                                                                                    root_dir  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                   2             R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                   3             R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R1        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R2        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                   4             R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#                                                 R0        /tungstenfs/scratch/gliberal/Users/repinico/Yo...
#
#                                                          channel_id  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0              C01
#                                                 R0              C02
#                                                 R0              C03
#                                                 R0              C04
#                                                 R1              C01
#                                                 R1              C02
#                                                 R1              C03
#                                                 R1              C04
#                                                 R2              C01
#                                                 R2              C02
#                                                 R2              C03
#                                                 R2              C04
#                                   2             R0              C01
#                                                 R0              C02
#                                                 R0              C03
#                                                 R0              C04
#                                                 R1              C01
#                                                 R1              C02
#                                                 R1              C03
#                                                 R1              C04
#                                                 R2              C01
#                                                 R2              C02
#                                                 R2              C03
#                                                 R2              C04
#                                   3             R0              C01
#                                                 R0              C02
#                                                 R0              C03
#                                                 R0              C04
#                                                 R1              C01
#                                                 R1              C02
#                                                 R1              C03
#                                                 R1              C04
#                                                 R2              C01
#                                                 R2              C02
#                                                 R2              C03
#                                                 R2              C04
#                                   4             R0              C01
#                                                 R0              C02
#                                                 R0              C03
#                                                 R0              C04
#
#                                                          object_type  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0           nucleus
#                                                 R0           nucleus
#                                                 R0           nucleus
#                                                 R0           nucleus
#                                                 R1           nucleus
#                                                 R1           nucleus
#                                                 R1           nucleus
#                                                 R1           nucleus
#                                                 R2           nucleus
#                                                 R2           nucleus
#                                                 R2           nucleus
#                                                 R2           nucleus
#                                   2             R0           nucleus
#                                                 R0           nucleus
#                                                 R0           nucleus
#                                                 R0           nucleus
#                                                 R1           nucleus
#                                                 R1           nucleus
#                                                 R1           nucleus
#                                                 R1           nucleus
#                                                 R2           nucleus
#                                                 R2           nucleus
#                                                 R2           nucleus
#                                                 R2           nucleus
#                                   3             R0           nucleus
#                                                 R0           nucleus
#                                                 R0           nucleus
#                                                 R0           nucleus
#                                                 R1           nucleus
#                                                 R1           nucleus
#                                                 R1           nucleus
#                                                 R1           nucleus
#                                                 R2           nucleus
#                                                 R2           nucleus
#                                                 R2           nucleus
#                                                 R2           nucleus
#                                   4             R0           nucleus
#                                                 R0           nucleus
#                                                 R0           nucleus
#                                                 R0           nucleus
#
#                                                          organoid_id  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0          object_2
#                                                 R0          object_2
#                                                 R0          object_2
#                                                 R0          object_2
#                                                 R1          object_4
#                                                 R1          object_4
#                                                 R1          object_4
#                                                 R1          object_4
#                                                 R2          object_4
#                                                 R2          object_4
#                                                 R2          object_4
#                                                 R2          object_4
#                                   2             R0          object_2
#                                                 R0          object_2
#                                                 R0          object_2
#                                                 R0          object_2
#                                                 R1          object_4
#                                                 R1          object_4
#                                                 R1          object_4
#                                                 R1          object_4
#                                                 R2          object_4
#                                                 R2          object_4
#                                                 R2          object_4
#                                                 R2          object_4
#                                   3             R0          object_2
#                                                 R0          object_2
#                                                 R0          object_2
#                                                 R0          object_2
#                                                 R1          object_4
#                                                 R1          object_4
#                                                 R1          object_4
#                                                 R1          object_4
#                                                 R2          object_4
#                                                 R2          object_4
#                                                 R2          object_4
#                                                 R2          object_4
#                                   4             R0          object_2
#                                                 R0          object_2
#                                                 R0          object_2
#                                                 R0          object_2
#
#                                                           org_label  nuc_id  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0                2       1
#                                                 R0                2       1
#                                                 R0                2       1
#                                                 R0                2       1
#                                                 R1                4       3
#                                                 R1                4       3
#                                                 R1                4       3
#                                                 R1                4       3
#                                                 R2                4       3
#                                                 R2                4       3
#                                                 R2                4       3
#                                                 R2                4       3
#                                   2             R0                2       2
#                                                 R0                2       2
#                                                 R0                2       2
#                                                 R0                2       2
#                                                 R1                4       1
#                                                 R1                4       1
#                                                 R1                4       1
#                                                 R1                4       1
#                                                 R2                4       4
#                                                 R2                4       4
#                                                 R2                4       4
#                                                 R2                4       4
#                                   3             R0                2       3
#                                                 R0                2       3
#                                                 R0                2       3
#                                                 R0                2       3
#                                                 R1                4       4
#                                                 R1                4       4
#                                                 R1                4       4
#                                                 R1                4       4
#                                                 R2                4       1
#                                                 R2                4       1
#                                                 R2                4       1
#                                                 R2                4       1
#                                   4             R0                2       4
#                                                 R0                2       4
#                                                 R0                2       4
#                                                 R0                2       4
#
#                                                                                            segmentation_nuc  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                   2             R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                   3             R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                   4             R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#
#                                                                                               intensity_img  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                   2             R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                   3             R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R1        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                                 R2        day1p5/obj_v0.3_ROI/B03/object_4/AssayPlate_Gr...
#                                   4             R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#                                                 R0        day1p5/obj_v0.3_ROI/B03/object_2/220509_092328...
#
#                                                            x_pos_vox  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0         74.146953
#                                                 R0         74.146953
#                                                 R0         74.146953
#                                                 R0         74.146953
#                                                 R1         50.365575
#                                                 R1         50.365575
#                                                 R1         50.365575
#                                                 R1         50.365575
#                                                 R2         78.145512
#                                                 R2         78.145512
#                                                 R2         78.145512
#                                                 R2         78.145512
#                                   2             R0        115.691916
#                                                 R0        115.691916
#                                                 R0        115.691916
#                                                 R0        115.691916
#                                                 R1         95.866471
#                                                 R1         95.866471
#                                                 R1         95.866471
#                                                 R1         95.866471
#                                                 R2        119.170884
#                                                 R2        119.170884
#                                                 R2        119.170884
#                                                 R2        119.170884
#                                   3             R0         94.544044
#                                                 R0         94.544044
#                                                 R0         94.544044
#                                                 R0         94.544044
#                                                 R1        116.903791
#                                                 R1        116.903791
#                                                 R1        116.903791
#                                                 R1        116.903791
#                                                 R2         98.444238
#                                                 R2         98.444238
#                                                 R2         98.444238
#                                                 R2         98.444238
#                                   4             R0         48.768371
#                                                 R0         48.768371
#                                                 R0         48.768371
#                                                 R0         48.768371
#
#                                                            y_pos_vox  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0        113.478193
#                                                 R0        113.478193
#                                                 R0        113.478193
#                                                 R0        113.478193
#                                                 R1         63.141140
#                                                 R1         63.141140
#                                                 R1         63.141140
#                                                 R1         63.141140
#                                                 R2        117.085195
#                                                 R2        117.085195
#                                                 R2        117.085195
#                                                 R2        117.085195
#                                   2             R0         88.466104
#                                                 R0         88.466104
#                                                 R0         88.466104
#                                                 R0         88.466104
#                                                 R1         52.308809
#                                                 R1         52.308809
#                                                 R1         52.308809
#                                                 R1         52.308809
#                                                 R2         91.833165
#                                                 R2         91.833165
#                                                 R2         91.833165
#                                                 R2         91.833165
#                                   3             R0         49.302692
#                                                 R0         49.302692
#                                                 R0         49.302692
#                                                 R0         49.302692
#                                                 R1         91.132317
#                                                 R1         91.132317
#                                                 R1         91.132317
#                                                 R1         91.132317
#                                                 R2         53.678585
#                                                 R2         53.678585
#                                                 R2         53.678585
#                                                 R2         53.678585
#                                   4             R0         60.048722
#                                                 R0         60.048722
#                                                 R0         60.048722
#                                                 R0         60.048722
#
#                                                           z_pos_vox  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0        53.220794
#                                                 R0        53.220794
#                                                 R0        53.220794
#                                                 R0        53.220794
#                                                 R1        58.410444
#                                                 R1        58.410444
#                                                 R1        58.410444
#                                                 R1        58.410444
#                                                 R2        53.645867
#                                                 R2        53.645867
#                                                 R2        53.645867
#                                                 R2        53.645867
#                                   2             R0        61.662317
#                                                 R0        61.662317
#                                                 R0        61.662317
#                                                 R0        61.662317
#                                                 R1        58.050561
#                                                 R1        58.050561
#                                                 R1        58.050561
#                                                 R1        58.050561
#                                                 R2        59.244939
#                                                 R2        59.244939
#                                                 R2        59.244939
#                                                 R2        59.244939
#                                   3             R0        61.274775
#                                                 R0        61.274775
#                                                 R0        61.274775
#                                                 R0        61.274775
#                                                 R1        62.152872
#                                                 R1        62.152872
#                                                 R1        62.152872
#                                                 R1        62.152872
#                                                 R2        53.468093
#                                                 R2        53.468093
#                                                 R2        53.468093
#                                                 R2        53.468093
#                                   4             R0        61.772458
#                                                 R0        61.772458
#                                                 R0        61.772458
#                                                 R0        61.772458
#
#                                                           volume_pix  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0             61632
#                                                 R0             61632
#                                                 R0             61632
#                                                 R0             61632
#                                                 R1             66126
#                                                 R1             66126
#                                                 R1             66126
#                                                 R1             66126
#                                                 R2             59088
#                                                 R2             59088
#                                                 R2             59088
#                                                 R2             59088
#                                   2             R0             37704
#                                                 R0             37704
#                                                 R0             37704
#                                                 R0             37704
#                                                 R1             56190
#                                                 R1             56190
#                                                 R1             56190
#                                                 R1             56190
#                                                 R2             35568
#                                                 R2             35568
#                                                 R2             35568
#                                                 R2             35568
#                                   3             R0             53946
#                                                 R0             53946
#                                                 R0             53946
#                                                 R0             53946
#                                                 R1             38385
#                                                 R1             38385
#                                                 R1             38385
#                                                 R1             38385
#                                                 R2             54957
#                                                 R2             54957
#                                                 R2             54957
#                                                 R2             54957
#                                   4             R0             63852
#                                                 R0             63852
#                                                 R0             63852
#                                                 R0             63852
#
#                                                           mean_intensity  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0            645.734862
#                                                 R0            841.662091
#                                                 R0            611.913941
#                                                 R0            946.839223
#                                                 R1           1622.446239
#                                                 R1            382.572271
#                                                 R1            199.502949
#                                                 R1            280.484076
#                                                 R2            559.070065
#                                                 R2            243.280920
#                                                 R2            650.039043
#                                                 R2            139.491927
#                                   2             R0            562.844685
#                                                 R0           3942.866805
#                                                 R0           2166.967139
#                                                 R0           2279.759230
#                                                 R1           1616.390069
#                                                 R1            350.221143
#                                                 R1            170.365243
#                                                 R1            281.717726
#                                                 R2            488.678981
#                                                 R2            350.234987
#                                                 R2            920.860830
#                                                 R2            145.518219
#                                   3             R0            612.804694
#                                                 R0            757.197865
#                                                 R0            529.074853
#                                                 R0           1290.387610
#                                                 R1           1518.126143
#                                                 R1            505.917468
#                                                 R1            256.890348
#                                                 R1            244.710199
#                                                 R2            527.422021
#                                                 R2            252.090507
#                                                 R2            654.373710
#                                                 R2            139.187237
#                                   4             R0            622.236892
#                                                 R0           1285.075832
#                                                 R0            908.136816
#                                                 R0           1224.784486
#
#                                                           max_intensity  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0               1602.0
#                                                 R0               4519.0
#                                                 R0               2878.0
#                                                 R0               5152.0
#                                                 R1               3589.0
#                                                 R1                890.0
#                                                 R1                461.0
#                                                 R1                507.0
#                                                 R2               1247.0
#                                                 R2                456.0
#                                                 R2               1597.0
#                                                 R2                228.0
#                                   2             R0               1621.0
#                                                 R0              23017.0
#                                                 R0               6932.0
#                                                 R0               9269.0
#                                                 R1               4184.0
#                                                 R1                682.0
#                                                 R1                356.0
#                                                 R1                473.0
#                                                 R2               1237.0
#                                                 R2               1011.0
#                                                 R2               2499.0
#                                                 R2                238.0
#                                   3             R0               1563.0
#                                                 R0               3305.0
#                                                 R0               1723.0
#                                                 R0              11235.0
#                                                 R1               4099.0
#                                                 R1               1338.0
#                                                 R1                697.0
#                                                 R1                531.0
#                                                 R2               1359.0
#                                                 R2                416.0
#                                                 R2               1284.0
#                                                 R2                213.0
#                                   4             R0               1334.0
#                                                 R0               8027.0
#                                                 R0               4667.0
# ...
#
#                                                           quartile99  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0           1165.00
#                                                 R0           2278.13
#                                                 R0           1513.00
#                                                 R0           2794.71
#                                                 R1           2943.00
#                                                 R1            603.00
#                                                 R1            339.00
#                                                 R1            389.00
#                                                 R2            998.00
#                                                 R2            329.05
#                                                 R2           1043.10
#                                                 R2            181.00
#                                   2             R0           1046.33
#                                                 R0          11296.29
#                                                 R0           5232.99
#                                                 R0           6655.28
#                                                 R1           3344.13
#                                                 R1            483.00
#                                                 R1            241.00
#                                                 R1            391.00
#                                                 R2            910.00
#                                                 R2            658.45
#                                                 R2           1842.90
#                                                 R2            200.00
#                                   3             R0           1212.00
#                                                 R0           1413.00
#                                                 R0            947.00
#                                                 R0           5836.33
#                                                 R1           2921.12
#                                                 R1            906.00
#                                                 R1            468.00
#                                                 R1            362.00
#                                                 R2           1025.82
#                                                 R2            327.00
#                                                 R2            921.00
#                                                 R2            178.00
#                                   4             R0           1086.00
#                                                 R0           4378.17
#                                                 R0           2613.34
#                                                 R0           3675.53
#
#                                                                 stdev  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0         206.660259
#                                                 R0         357.419871
#                                                 R0         224.740186
#                                                 R0         493.319733
#                                                 R1         521.373487
#                                                 R1          69.020262
#                                                 R1          41.034608
#                                                 R1          46.525293
#                                                 R2         170.446973
#                                                 R2          31.594104
#                                                 R2         138.240115
#                                                 R2          15.373959
#                                   2             R0         177.676341
#                                                 R0        2247.760458
#                                                 R0         972.451230
#                                                 R0        1301.907534
#                                                 R1         517.613852
#                                                 R1          49.918443
#                                                 R1          25.182591
#                                                 R1          50.059139
#                                                 R2         150.121697
#                                                 R2          91.060536
#                                                 R2         298.491561
#                                                 R2          18.370391
#                                   3             R0         181.942719
#                                                 R0         202.826801
#                                                 R0         123.275600
#                                                 R0        1004.617845
#                                                 R1         514.761183
#                                                 R1         127.665423
#                                                 R1          64.995393
#                                                 R1          41.908572
#                                                 R2         154.064770
#                                                 R2          29.718193
#                                                 R2         117.226057
#                                                 R2          14.585685
#                                   4             R0         186.615996
#                                                 R0         771.567810
#                                                 R0         440.377252
#                                                 R0         669.539129
#
#                                                               skew   kurtosis  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0        0.391605  -0.267346
#                                                 R0        2.821364  14.135520
#                                                 R0        2.685296  12.936765
#                                                 R0        1.977734   6.087785
#                                                 R1        0.275353  -0.194106
#                                                 R1        0.889550   2.747146
#                                                 R1        1.353960   3.293927
#                                                 R1       -0.052579   0.101430
#                                                 R2        0.425874  -0.118639
#                                                 R2        0.556675   1.233884
#                                                 R2        0.554235   1.449375
#                                                 R2        0.431490   0.593895
#                                   2             R0        0.812321   1.094607
#                                                 R0        1.730889   4.732400
#                                                 R0        1.168364   1.371235
#                                                 R0        1.346907   2.186818
#                                                 R1        0.904210   1.896215
#                                                 R1        0.416386   1.158975
#                                                 R1        0.708270   1.412353
#                                                 R1       -0.132114  -0.104511
#                                                 R2        0.850487   0.791184
#                                                 R2        1.512815   3.128898
#                                                 R2        1.232359   1.499714
#                                                 R2        0.767547   1.029415
#                                   3             R0        0.973468   1.913621
#                                                 R0        1.707155   8.119635
#                                                 R0        1.520033   5.204302
#                                                 R0        3.736741  20.130523
#                                                 R1        0.693778   0.624201
#                                                 R1        1.213898   1.845751
#                                                 R1        1.266647   2.392288
#                                                 R1        0.748901   1.009926
#                                                 R2        0.968872   1.825982
#                                                 R2        0.251102   0.313031
#                                                 R2       -0.205023   0.263579
#                                                 R2        0.380367   0.500378
#                                   4             R0        0.301480  -0.288376
#                                                 R0        2.445852   8.605102
#                                                 R0        2.154812   6.335253
#                                                 R0        2.155023   7.165981
#
#                                                                       id  \
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0        day1p5_B03_2_1
#                                                 R0        day1p5_B03_2_1
#                                                 R0        day1p5_B03_2_1
#                                                 R0        day1p5_B03_2_1
#                                                 R1        day1p5_B03_2_1
#                                                 R1        day1p5_B03_2_1
#                                                 R1        day1p5_B03_2_1
#                                                 R1        day1p5_B03_2_1
#                                                 R2        day1p5_B03_4_3
#                                                 R2        day1p5_B03_4_3
#                                                 R2        day1p5_B03_4_3
#                                                 R2        day1p5_B03_4_3
#                                   2             R0        day1p5_B03_2_2
#                                                 R0        day1p5_B03_2_2
#                                                 R0        day1p5_B03_2_2
#                                                 R0        day1p5_B03_2_2
#                                                 R1        day1p5_B03_2_2
#                                                 R1        day1p5_B03_2_2
#                                                 R1        day1p5_B03_2_2
#                                                 R1        day1p5_B03_2_2
#                                                 R2        day1p5_B03_4_4
#                                                 R2        day1p5_B03_4_4
#                                                 R2        day1p5_B03_4_4
#                                                 R2        day1p5_B03_4_4
#                                   3             R0        day1p5_B03_2_3
#                                                 R0        day1p5_B03_2_3
#                                                 R0        day1p5_B03_2_3
#                                                 R0        day1p5_B03_2_3
#                                                 R1        day1p5_B03_2_3
#                                                 R1        day1p5_B03_2_3
#                                                 R1        day1p5_B03_2_3
#                                                 R1        day1p5_B03_2_3
#                                                 R2        day1p5_B03_4_1
#                                                 R2        day1p5_B03_4_1
#                                                 R2        day1p5_B03_4_1
#                                                 R2        day1p5_B03_4_1
#                                   4             R0        day1p5_B03_2_4
#                                                 R0        day1p5_B03_2_4
#                                                 R0        day1p5_B03_2_4
#                                                 R0        day1p5_B03_2_4
#
#                                                          organoid_id_linked
# plate_id well_id org_label_linked nuc_id_linked round_id
# day1p5   B03     2                1             R0                 object_2
#                                                 R0                 object_2
#                                                 R0                 object_2
#                                                 R0                 object_2
#                                                 R1                 object_2
#                                                 R1                 object_2
#                                                 R1                 object_2
#                                                 R1                 object_2
#                                                 R2                 object_2
#                                                 R2                 object_2
#                                                 R2                 object_2
#                                                 R2                 object_2
#                                   2             R0                 object_2
#                                                 R0                 object_2
#                                                 R0                 object_2
#                                                 R0                 object_2
#                                                 R1                 object_2
#                                                 R1                 object_2
#                                                 R1                 object_2
#                                                 R1                 object_2
#                                                 R2                 object_2
#                                                 R2                 object_2
#                                                 R2                 object_2
#                                                 R2                 object_2
#                                   3             R0                 object_2
#                                                 R0                 object_2
#                                                 R0                 object_2
#                                                 R0                 object_2
#                                                 R1                 object_2
#                                                 R1                 object_2
#                                                 R1                 object_2
#                                                 R1                 object_2
#                                                 R2                 object_2
#                                                 R2                 object_2
#                                                 R2                 object_2
#                                                 R2                 object_2
#                                   4             R0                 object_2
#                                                 R0                 object_2
#                                                 R0                 object_2
#                                                 R0                 object_2

# %%
#TODO make all nuc_id and cell_id integers

# %%
#to add marker labels (ex. DAPI, Lyz, Agr2) make a dictionary with 
#key plate_id + channel_id + round_id
#values markers
#add to pooled dataframes
